# %% [markdown]
# The lab is based on the 2022 Stack Overflow Annual Developer Survey (https://insights.stackoverflow.com/survey)
#
# Please make sure to download the Zipped file to your local machine and upload the CSVs to the DataPlatfrom Asset
#
# From the Data section of this screen you can choose Insert to Code -> Pandas DataFrame

# %% [markdown]
# The DataFrame has several attributes and properties
# For complete reference please link to (https://pandas.pydata.org/docs/)
# The following commands can be found here (https://pandas.pydata.org/docs/reference/io.html#)
#
# DataFrame.info will print information about the DataFrame including the index type and columns, non-null values and memory usage.

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='LSwCEs_cfscjTqJ4eSLO53zpulip0Lw4sC9WDNUe86hh',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'testiai-donotdelete-pr-uujzafxiu7cgp8'
object_key = 'survey_results_public.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %% [markdown]
# The head function returns the first n rows for the object based on position.
# It's useful for quickly testing if your object has the right type of data in it.

# %%
df.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# 13          14                     I am a developer by profession
# 14          15                     I am a developer by profession
# 15          16                     I am a developer by profession
# 16          17                     I am a developer by profession
# 17          18                     I am a developer by profession
# 18          19                     I am a developer by profession
# 19          20                              I am learning to code
# 20          21                     I am a developer by profession
# 21          22                     I am a developer by profession
# 22          23                     I am a developer by profession
# 23          24  I am not primarily a developer, but I write co...
# 24          25                     I am a developer by profession
# 25          26                     I am a developer by profession
# 26          27                     I am a developer by profession
# 27          28                     I am a developer by profession
# 28          29                     I am a developer by profession
# 29          30                     I am a developer by profession
# 30          31                                      None of these
# 31          32                     I am a developer by profession
# 32          33                        I code primarily as a hobby
# 33          34  I am not primarily a developer, but I write co...
# 34          35                     I am a developer by profession
# 35          36  I am not primarily a developer, but I write co...
# 36          37                     I am a developer by profession
# 37          38                     I am a developer by profession
# 38          39                        I code primarily as a hobby
# 39          40                     I am a developer by profession
# 40          41                     I am a developer by profession
# 41          42                     I am a developer by profession
# 42          43                     I am a developer by profession
# 43          44                        I code primarily as a hobby
# 44          45                     I am a developer by profession
# 45          46                     I am a developer by profession
# 46          47                        I code primarily as a hobby
# 47          48                     I am a developer by profession
# 48          49                     I am a developer by profession
# 49          50                     I am a developer by profession
#
#                                            Employment  \
# 0                                                 NaN
# 1                                 Employed, full-time
# 2                                 Employed, full-time
# 3                                 Employed, full-time
# 4                                 Employed, full-time
# 5                                  Student, full-time
# 6                                  Student, part-time
# 7                  Not employed, but looking for work
# 8                                 Employed, full-time
# 9   Independent contractor, freelancer, or self-em...
# 10                                Employed, full-time
# 11  Employed, full-time;Independent contractor, fr...
# 12                                Employed, full-time
# 13                                Employed, part-time
# 14  Employed, full-time;Independent contractor, fr...
# 15  Independent contractor, freelancer, or self-em...
# 16                                Employed, full-time
# 17                                Employed, full-time
# 18                                Employed, full-time
# 19                                 Student, full-time
# 20             Student, part-time;Employed, part-time
# 21                                Employed, full-time
# 22                                Employed, full-time
# 23                                Employed, full-time
# 24  Independent contractor, freelancer, or self-em...
# 25                                Employed, full-time
# 26                                Employed, full-time
# 27             Not employed, and not looking for work
# 28                                Employed, full-time
# 29  Employed, full-time;Independent contractor, fr...
# 30                                                NaN
# 31                                Employed, full-time
# 32             Student, full-time;Employed, part-time
# 33             Student, part-time;Employed, part-time
# 34  Independent contractor, freelancer, or self-em...
# 35                                 Student, full-time
# 36                                Employed, full-time
# 37  Independent contractor, freelancer, or self-em...
# 38                                 Student, full-time
# 39                                Employed, full-time
# 40                                Employed, full-time
# 41                                Employed, full-time
# 42                 Not employed, but looking for work
# 43             Employed, full-time;Student, part-time
# 44                                 Student, full-time
# 45                                Employed, full-time
# 46                                 Student, full-time
# 47                                Employed, full-time
# 48                                Employed, full-time
# 49                                Employed, full-time
#
#                               RemoteWork  \
# 0                                    NaN
# 1                           Fully remote
# 2   Hybrid (some remote, some in-person)
# 3                           Fully remote
# 4   Hybrid (some remote, some in-person)
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8   Hybrid (some remote, some in-person)
# 9                           Fully remote
# 10  Hybrid (some remote, some in-person)
# 11                          Fully remote
# 12  Hybrid (some remote, some in-person)
# 13                          Fully remote
# 14                          Fully remote
# 15                          Fully remote
# 16  Hybrid (some remote, some in-person)
# 17                          Fully remote
# 18  Hybrid (some remote, some in-person)
# 19                                   NaN
# 20  Hybrid (some remote, some in-person)
# 21  Hybrid (some remote, some in-person)
# 22                          Fully remote
# 23  Hybrid (some remote, some in-person)
# 24                          Fully remote
# 25  Hybrid (some remote, some in-person)
# 26  Hybrid (some remote, some in-person)
# 27                                   NaN
# 28  Hybrid (some remote, some in-person)
# 29                          Fully remote
# 30                                   NaN
# 31                          Fully remote
# 32                        Full in-person
# 33                        Full in-person
# 34                          Fully remote
# 35                                   NaN
# 36                          Fully remote
# 37                          Fully remote
# 38                                   NaN
# 39  Hybrid (some remote, some in-person)
# 40  Hybrid (some remote, some in-person)
# 41  Hybrid (some remote, some in-person)
# 42                                   NaN
# 43                        Full in-person
# 44                                   NaN
# 45  Hybrid (some remote, some in-person)
# 46                                   NaN
# 47                          Fully remote
# 48  Hybrid (some remote, some in-person)
# 49                          Fully remote
#
#                                      CodingActivities  \
# 0                                                 NaN
# 1            Hobby;Contribute to open-source projects
# 2                                               Hobby
# 3                        I don’t code outside of work
# 4                                               Hobby
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                        I don’t code outside of work
# 9   Hobby;Contribute to open-source projects;Boots...
# 10                       I don’t code outside of work
# 11  Hobby;Contribute to open-source projects;Freel...
# 12                                              Hobby
# 13                                              Hobby
# 14                      Hobby;Freelance/contract work
# 15           Hobby;Contribute to open-source projects
# 16                                              Hobby
# 17                                              Hobby
# 18                                              Hobby
# 19                                                NaN
# 20                                              Hobby
# 21                       I don’t code outside of work
# 22           Hobby;Contribute to open-source projects
# 23                       I don’t code outside of work
# 24                       I don’t code outside of work
# 25                                              Hobby
# 26                       I don’t code outside of work
# 27                                                NaN
# 28           Hobby;Contribute to open-source projects
# 29                     Hobby;Bootstrapping a business
# 30                                                NaN
# 31                       I don’t code outside of work
# 32           Hobby;Contribute to open-source projects
# 33                                              Hobby
# 34  Hobby;Contribute to open-source projects;Boots...
# 35                                                NaN
# 36                       I don’t code outside of work
# 37                       I don’t code outside of work
# 38                                                NaN
# 39                                              Hobby
# 40                      Hobby;Freelance/contract work
# 41                       I don’t code outside of work
# 42                                                NaN
# 43                                              Hobby
# 44                                                NaN
# 45                            Other (please specify):
# 46                                                NaN
# 47                                              Hobby
# 48           Hobby;Contribute to open-source projects
# 49                                              Hobby
#
#                                               EdLevel  \
# 0                                                 NaN
# 1                                                 NaN
# 2     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6   Secondary school (e.g. American high school, G...
# 7   Some college/university study without earning ...
# 8     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9   Some college/university study without earning ...
# 10       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18  Secondary school (e.g. American high school, G...
# 19  Some college/university study without earning ...
# 20  Some college/university study without earning ...
# 21    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22                                     Something else
# 23    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24  Some college/university study without earning ...
# 25    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 27                                     Something else
# 28    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 29    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 30                                                NaN
# 31       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32                          Primary/elementary school
# 33  Some college/university study without earning ...
# 34    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35         Other doctoral degree (Ph.D., Ed.D., etc.)
# 36       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37  Secondary school (e.g. American high school, G...
# 38  Secondary school (e.g. American high school, G...
# 39    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 40                Associate degree (A.A., A.S., etc.)
# 41  Secondary school (e.g. American high school, G...
# 42       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43  Some college/university study without earning ...
# 44  Secondary school (e.g. American high school, G...
# 45    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46  Secondary school (e.g. American high school, G...
# 47       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48  Some college/university study without earning ...
# 49  Secondary school (e.g. American high school, G...
#
#                                             LearnCode  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Books / Physical media;Friend or family member...
# 3   Books / Physical media;School (i.e., Universit...
# 4   Other online resources (e.g., videos, blogs, f...
# 5   Books / Physical media;School (i.e., Universit...
# 6   Other online resources (e.g., videos, blogs, f...
# 7                     Online Courses or Certification
# 8                 On the job training;Coding Bootcamp
# 9   Books / Physical media;Other online resources ...
# 10  Books / Physical media;Friend or family member...
# 11  Other online resources (e.g., videos, blogs, f...
# 12            School (i.e., University, College, etc)
# 13  Books / Physical media;School (i.e., Universit...
# 14  Other online resources (e.g., videos, blogs, f...
# 15                             Books / Physical media
# 16  Books / Physical media;Other online resources ...
# 17  Other online resources (e.g., videos, blogs, f...
# 18  Books / Physical media;School (i.e., Universit...
# 19   Books / Physical media;Coding Bootcamp;Colleague
# 20  Books / Physical media;Other online resources ...
# 21                            Other (please specify):
# 22                             Books / Physical media
# 23  Other online resources (e.g., videos, blogs, f...
# 24                                                NaN
# 25  Books / Physical media;Other online resources ...
# 26  Books / Physical media;Other online resources ...
# 27  Other online resources (e.g., videos, blogs, f...
# 28  Books / Physical media;School (i.e., Universit...
# 29  Books / Physical media;Other online resources ...
# 30                                                NaN
# 31  Books / Physical media;Other online resources ...
# 32  Other online resources (e.g., videos, blogs, f...
# 33  Friend or family member;Other online resources...
# 34  Other online resources (e.g., videos, blogs, f...
# 35  Other online resources (e.g., videos, blogs, f...
# 36  Books / Physical media;Other online resources ...
# 37  Books / Physical media;Friend or family member...
# 38  Friend or family member;Other online resources...
# 39  Books / Physical media;Other online resources ...
# 40  Books / Physical media;Other online resources ...
# 41  Other online resources (e.g., videos, blogs, f...
# 42  Other online resources (e.g., videos, blogs, f...
# 43  Books / Physical media;Other online resources ...
# 44            School (i.e., University, College, etc)
# 45  Other online resources (e.g., videos, blogs, f...
# 46  Other online resources (e.g., videos, blogs, f...
# 47  Friend or family member;Other online resources...
# 48  Books / Physical media;Other online resources ...
# 49  Other online resources (e.g., videos, blogs, f...
#
#                                       LearnCodeOnline  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Technical documentation;Blogs;Programming Game...
# 3                                                 NaN
# 4   Technical documentation;Blogs;Stack Overflow;O...
# 5                                                 NaN
# 6           Stack Overflow;Video-based Online Courses
# 7                                                 NaN
# 8                                                 NaN
# 9   Technical documentation;Blogs;Written Tutorial...
# 10  Technical documentation;Blogs;Written Tutorial...
# 11  Technical documentation;Blogs;Written Tutorial...
# 12                                                NaN
# 13                                                NaN
# 14  Written Tutorials;Stack Overflow;Video-based O...
# 15                                                NaN
# 16  Technical documentation;Blogs;Written Tutorial...
# 17  Technical documentation;Written Tutorials;Stac...
# 18                                                NaN
# 19                                                NaN
# 20  Technical documentation;Blogs;Stack Overflow;V...
# 21                                                NaN
# 22                                                NaN
# 23  Blogs;Written Tutorials;Stack Overflow;Written...
# 24                                                NaN
# 25  Technical documentation;Blogs;Written Tutorial...
# 26  Technical documentation;Stack Overflow;Online ...
# 27  Technical documentation;Written Tutorials;Stac...
# 28                                                NaN
# 29       Technical documentation;Blogs;Stack Overflow
# 30                                                NaN
# 31  Technical documentation;Blogs;Stack Overflow;O...
# 32  Technical documentation;Online challenges (e.g...
# 33  Technical documentation;Blogs;Written Tutorial...
# 34                      Technical documentation;Blogs
# 35  Technical documentation;Blogs;Stack Overflow;O...
# 36  Technical documentation;Blogs;Written Tutorial...
# 37  Technical documentation;Blogs;Written Tutorial...
# 38  Blogs;Written Tutorials;Stack Overflow;Video-b...
# 39  Technical documentation;Blogs;Written Tutorial...
# 40  Technical documentation;Blogs;Written Tutorial...
# 41  Technical documentation;Blogs;Written Tutorial...
# 42  Technical documentation;Blogs;Stack Overflow;V...
# 43  Technical documentation;Written Tutorials;Stac...
# 44                                                NaN
# 45  Technical documentation;Video-based Online Cou...
# 46        Technical documentation;Blogs;How-to videos
# 47  Technical documentation;Blogs;Written Tutorial...
# 48  Technical documentation;Blogs;Written Tutorial...
# 49       Technical documentation;Blogs;Stack Overflow
#
#                      LearnCodeCoursesCert YearsCode  ...  \
# 0                                     NaN       NaN  ...
# 1                                     NaN       NaN  ...
# 2                                     NaN        14  ...
# 3                                     NaN        20  ...
# 4                                     NaN         8  ...
# 5                                     NaN        15  ...
# 6                                     NaN         3  ...
# 7                          Coursera;Udemy         1  ...
# 8                                     NaN         6  ...
# 9                                     NaN        37  ...
# 10                                    NaN         5  ...
# 11                                    NaN        12  ...
# 12                                    NaN        12  ...
# 13                                    NaN        22  ...
# 14                                    NaN        11  ...
# 15                                    NaN         4  ...
# 16                       Udemy;Codecademy         7  ...
# 17                   Coursera;Pluralsight        13  ...
# 18                                    NaN        36  ...
# 19                                    NaN         2  ...
# 20                                    NaN         1  ...
# 21                                    NaN         5  ...
# 22                                    NaN        25  ...
# 23                                    NaN        10  ...
# 24                                    NaN        40  ...
# 25  Coursera;Udemy;Codecademy;edX;Udacity        16  ...
# 26                                    NaN        10  ...
# 27                                    NaN         4  ...
# 28                                    NaN        20  ...
# 29                                    NaN        27  ...
# 30                                    NaN       NaN  ...
# 31                                    NaN        24  ...
# 32                                    NaN         3  ...
# 33                                    NaN         8  ...
# 34         Coursera;Udemy;Pluralsight;edX         6  ...
# 35                                    NaN        16  ...
# 36                                  Udemy        12  ...
# 37                                    NaN        19  ...
# 38                                  Other         2  ...
# 39                       Udemy;Codecademy        24  ...
# 40                                    NaN        20  ...
# 41                 Coursera;Udemy;Udacity         3  ...
# 42                      Udemy;Pluralsight         4  ...
# 43                                    NaN        15  ...
# 44                                    NaN         6  ...
# 45                                  Udemy         4  ...
# 46                                    NaN         7  ...
# 47                                    NaN         6  ...
# 48                                    NaN        40  ...
# 49                                    NaN         7  ...
#
#                  TimeSearching               TimeAnswering      Onboarding  \
# 0                          NaN                         NaN             NaN
# 1                          NaN                         NaN             NaN
# 2                          NaN                         NaN             NaN
# 3                          NaN                         NaN             NaN
# 4                          NaN                         NaN             NaN
# 5                          NaN                         NaN             NaN
# 6                          NaN                         NaN             NaN
# 7                          NaN                         NaN             NaN
# 8          15-30 minutes a day      Over 120 minutes a day   Somewhat long
# 9                          NaN                         NaN             NaN
# 10                         NaN                         NaN             NaN
# 11         30-60 minutes a day        60-120 minutes a day      Just right
# 12         30-60 minutes a day  Less than 15 minutes a day  Somewhat short
# 13        60-120 minutes a day         30-60 minutes a day      Very short
# 14         30-60 minutes a day         30-60 minutes a day   Somewhat long
# 15                         NaN                         NaN             NaN
# 16                         NaN                         NaN             NaN
# 17                         NaN                         NaN             NaN
# 18                         NaN                         NaN             NaN
# 19                         NaN                         NaN             NaN
# 20                         NaN                         NaN             NaN
# 21         30-60 minutes a day        60-120 minutes a day   Somewhat long
# 22         30-60 minutes a day         15-30 minutes a day   Somewhat long
# 23                         NaN                         NaN             NaN
# 24                         NaN                         NaN             NaN
# 25         30-60 minutes a day        60-120 minutes a day  Somewhat short
# 26                         NaN                         NaN             NaN
# 27                         NaN                         NaN             NaN
# 28         30-60 minutes a day         15-30 minutes a day   Somewhat long
# 29         15-30 minutes a day         15-30 minutes a day   Somewhat long
# 30                         NaN                         NaN             NaN
# 31         30-60 minutes a day         15-30 minutes a day       Very long
# 32                         NaN                         NaN             NaN
# 33                         NaN                         NaN             NaN
# 34         30-60 minutes a day         30-60 minutes a day   Somewhat long
# 35                         NaN                         NaN             NaN
# 36         30-60 minutes a day         15-30 minutes a day  Somewhat short
# 37                         NaN                         NaN             NaN
# 38                         NaN                         NaN             NaN
# 39                         NaN                         NaN             NaN
# 40                         NaN                         NaN             NaN
# 41         30-60 minutes a day         15-30 minutes a day  Somewhat short
# 42                         NaN                         NaN             NaN
# 43                         NaN                         NaN             NaN
# 44                         NaN                         NaN             NaN
# 45  Less than 15 minutes a day         15-30 minutes a day       Very long
# 46                         NaN                         NaN             NaN
# 47         30-60 minutes a day         30-60 minutes a day   Somewhat long
# 48         15-30 minutes a day  Less than 15 minutes a day      Just right
# 49         30-60 minutes a day         15-30 minutes a day   Somewhat long
#
#                                      ProfessionalTech TrueFalse_1 TrueFalse_2  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8   Innersource initiative;DevOps function;Microse...         Yes         Yes
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11  Innersource initiative;DevOps function;Microse...         Yes         Yes
# 12                      DevOps function;Microservices         Yes          No
# 13  Continuous integration (CI) and (more often) c...          No          No
# 14  DevOps function;Continuous integration (CI) an...          No         Yes
# 15                                                NaN         NaN         NaN
# 16                                                NaN         NaN         NaN
# 17                                                NaN         NaN         NaN
# 18                                                NaN         NaN         NaN
# 19                                                NaN         NaN         NaN
# 20                                                NaN         NaN         NaN
# 21                                      None of these         Yes          No
# 22  DevOps function;Microservices;Continuous integ...          No          No
# 23                                                NaN         NaN         NaN
# 24                                                NaN         NaN         NaN
# 25  DevOps function;Microservices;Continuous integ...         Yes          No
# 26                                                NaN         NaN         NaN
# 27                                                NaN         NaN         NaN
# 28  Developer portal or other central places to fi...         Yes         Yes
# 29  DevOps function;Continuous integration (CI) an...         Yes         Yes
# 30                                                NaN         NaN         NaN
# 31                                    DevOps function          No         Yes
# 32                                                NaN         NaN         NaN
# 33                                                NaN         NaN         NaN
# 34  DevOps function;Developer portal or other cent...         Yes         Yes
# 35                                                NaN         NaN         NaN
# 36  Continuous integration (CI) and (more often) c...         Yes         Yes
# 37                                                NaN         NaN         NaN
# 38                                                NaN         NaN         NaN
# 39                                                NaN         NaN         NaN
# 40                                                NaN         NaN         NaN
# 41                                                NaN         NaN         Yes
# 42                                                NaN         NaN         NaN
# 43                                                NaN         NaN         NaN
# 44                                                NaN         NaN         NaN
# 45                                      Microservices          No         Yes
# 46                                                NaN         NaN         NaN
# 47  DevOps function;Microservices;Developer portal...         Yes         Yes
# 48  Continuous integration (CI) and (more often) c...         Yes          No
# 49  Continuous integration (CI) and (more often) c...          No          No
#
#    TrueFalse_3           SurveyLength                  SurveyEase  \
# 0          NaN                    NaN                         NaN
# 1          NaN               Too long                   Difficult
# 2          NaN  Appropriate in length  Neither easy nor difficult
# 3          NaN  Appropriate in length                        Easy
# 4          NaN               Too long                        Easy
# 5          NaN  Appropriate in length                        Easy
# 6          NaN  Appropriate in length                        Easy
# 7          NaN  Appropriate in length                        Easy
# 8          Yes  Appropriate in length                        Easy
# 9          NaN  Appropriate in length                        Easy
# 10         NaN  Appropriate in length                        Easy
# 11          No              Too short                        Easy
# 12         Yes  Appropriate in length                        Easy
# 13          No              Too short                        Easy
# 14         Yes  Appropriate in length                        Easy
# 15         NaN                    NaN  Neither easy nor difficult
# 16         NaN  Appropriate in length  Neither easy nor difficult
# 17         NaN  Appropriate in length                        Easy
# 18         NaN  Appropriate in length                        Easy
# 19         NaN  Appropriate in length                        Easy
# 20         NaN  Appropriate in length                        Easy
# 21          No  Appropriate in length                        Easy
# 22          No               Too long  Neither easy nor difficult
# 23         NaN  Appropriate in length  Neither easy nor difficult
# 24         NaN              Too short                        Easy
# 25         Yes  Appropriate in length  Neither easy nor difficult
# 26         NaN  Appropriate in length                        Easy
# 27         NaN  Appropriate in length                        Easy
# 28          No  Appropriate in length                        Easy
# 29         Yes               Too long                        Easy
# 30         NaN                    NaN                         NaN
# 31         Yes  Appropriate in length                        Easy
# 32         NaN  Appropriate in length                        Easy
# 33         NaN  Appropriate in length                        Easy
# 34         Yes               Too long                        Easy
# 35         NaN  Appropriate in length  Neither easy nor difficult
# 36         Yes  Appropriate in length                        Easy
# 37         NaN  Appropriate in length  Neither easy nor difficult
# 38         NaN  Appropriate in length                        Easy
# 39         NaN  Appropriate in length  Neither easy nor difficult
# 40         NaN  Appropriate in length                        Easy
# 41         Yes  Appropriate in length  Neither easy nor difficult
# 42         NaN  Appropriate in length                        Easy
# 43         NaN  Appropriate in length  Neither easy nor difficult
# 44         NaN  Appropriate in length                        Easy
# 45         Yes               Too long                        Easy
# 46         NaN              Too short  Neither easy nor difficult
# 47         Yes  Appropriate in length                        Easy
# 48         Yes  Appropriate in length                        Easy
# 49         Yes  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0                  NaN
# 1                  NaN
# 2              40205.0
# 3             215232.0
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8              49056.0
# 9                  NaN
# 10             60307.0
# 11            194400.0
# 12             65000.0
# 13                 NaN
# 14            110000.0
# 15                 NaN
# 16             19224.0
# 17            202623.0
# 18             51192.0
# 19                 NaN
# 20                 NaN
# 21             34126.0
# 22             97605.0
# 23                 NaN
# 24                 NaN
# 25             90647.0
# 26            106960.0
# 27                 NaN
# 28            130000.0
# 29           1663644.0
# 30                 NaN
# 31            102000.0
# 32                 NaN
# 33                 NaN
# 34             83256.0
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40            130000.0
# 41             68160.0
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45              5124.0
# 46                 NaN
# 47            135000.0
# 48            106644.0
# 49             51192.0
#
# [50 rows x 79 columns]

# %% [markdown]
# The tail function returns last n rows from the object based on position.
# It's useful for quickly verifying data, for example, after sorting or appending rows.

# %%
df.tail(14)
# Out:
#        ResponseId                                         MainBranch  \
# 73254       73255  I am not primarily a developer, but I write co...
# 73255       73256                     I am a developer by profession
# 73256       73257                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73254                                Employed, full-time
# 73255                                Employed, full-time
# 73256             Student, part-time;Employed, part-time
# 73257                                 Student, full-time
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# 73260             Employed, full-time;Student, part-time
# 73261                                Employed, full-time
# 73262             Student, full-time;Employed, part-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73254  Hybrid (some remote, some in-person)
# 73255  Hybrid (some remote, some in-person)
# 73256  Hybrid (some remote, some in-person)
# 73257                                   NaN
# 73258  Hybrid (some remote, some in-person)
# 73259  Hybrid (some remote, some in-person)
# 73260  Hybrid (some remote, some in-person)
# 73261  Hybrid (some remote, some in-person)
# 73262  Hybrid (some remote, some in-person)
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73254                                              Hobby
# 73255                      Hobby;Freelance/contract work
# 73256                            School or academic work
# 73257                                                NaN
# 73258                                              Hobby
# 73259                            Other (please specify):
# 73260                            School or academic work
# 73261                                              Hobby
# 73262                            School or academic work
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# 73254    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73255       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73256       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73257  Secondary school (e.g. American high school, G...
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73259    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73260       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73262  Secondary school (e.g. American high school, G...
# 73263       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73254  Books / Physical media;Friend or family member...
# 73255  Other online resources (e.g., videos, blogs, f...
# 73256  Books / Physical media;Other online resources ...
# 73257  Books / Physical media;Other online resources ...
# 73258  Other online resources (e.g., videos, blogs, f...
# 73259  Books / Physical media;Other online resources ...
# 73260            School (i.e., University, College, etc)
# 73261  Books / Physical media;Other online resources ...
# 73262  Other online resources (e.g., videos, blogs, f...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73254  Technical documentation;Blogs;Written Tutorial...
# 73255  Technical documentation;Blogs;Stack Overflow;O...
# 73256  Technical documentation;Stack Overflow;Online ...
# 73257  Technical documentation;Blogs;Written Tutorial...
# 73258  Stack Overflow;Video-based Online Courses;Onli...
# 73259  Technical documentation;Blogs;Written Tutorial...
# 73260                                                NaN
# 73261  Technical documentation;Blogs;Programming Game...
# 73262  Technical documentation;Written Tutorials;Stac...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...         TimeSearching  \
# 73254     Coursera;Udemy;Codecademy;edX         7  ...  60-120 minutes a day
# 73255                               NaN        14  ...  60-120 minutes a day
# 73256                    Coursera;Udemy         9  ...                   NaN
# 73257                               NaN         7  ...                   NaN
# 73258                    Coursera;Udemy         5  ...   15-30 minutes a day
# 73259                               NaN         6  ...   15-30 minutes a day
# 73260                               NaN         8  ...   15-30 minutes a day
# 73261      Udemy;Codecademy;Pluralsight         9  ...   15-30 minutes a day
# 73262                               NaN         4  ...                   NaN
# 73263                             Udemy         8  ...   30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...   15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...   30-60 minutes a day
# 73266                               NaN        50  ...                   NaN
# 73267                 Udemy;Pluralsight        16  ...                   NaN
#
#                     TimeAnswering      Onboarding  \
# 73254         30-60 minutes a day   Somewhat long
# 73255  Less than 15 minutes a day   Somewhat long
# 73256                         NaN             NaN
# 73257                         NaN             NaN
# 73258         15-30 minutes a day      Just right
# 73259  Less than 15 minutes a day  Somewhat short
# 73260         30-60 minutes a day       Very long
# 73261         15-30 minutes a day   Somewhat long
# 73262                         NaN             NaN
# 73263  Less than 15 minutes a day      Just right
# 73264        60-120 minutes a day       Very long
# 73265        60-120 minutes a day      Just right
# 73266                         NaN             NaN
# 73267                         NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 73254  Developer portal or other central places to fi...         Yes
# 73255  DevOps function;Microservices;Continuous integ...         Yes
# 73256                                                NaN         NaN
# 73257                                                NaN         NaN
# 73258  DevOps function;Microservices;Developer portal...         Yes
# 73259  DevOps function;Continuous integration (CI) an...         Yes
# 73260  DevOps function;Developer portal or other cent...          No
# 73261  Innersource initiative;DevOps function;Microse...         Yes
# 73262                                                NaN         NaN
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 73254         Yes         Yes  Appropriate in length
# 73255         Yes         Yes               Too long
# 73256         NaN         NaN  Appropriate in length
# 73257         NaN         NaN              Too short
# 73258         Yes         Yes               Too long
# 73259         Yes         Yes  Appropriate in length
# 73260          No         Yes  Appropriate in length
# 73261         Yes         Yes  Appropriate in length
# 73262         NaN         NaN  Appropriate in length
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 73254  Neither easy nor difficult                 NaN
# 73255  Neither easy nor difficult                 NaN
# 73256                        Easy                 NaN
# 73257                        Easy                 NaN
# 73258  Neither easy nor difficult                 NaN
# 73259  Neither easy nor difficult                 NaN
# 73260                        Easy                 NaN
# 73261                        Easy                 NaN
# 73262  Neither easy nor difficult                 NaN
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [14 rows x 79 columns]

# %% [markdown]
# DataFrame.Column name will show the content of a specific column its less recommended
# Mistakes and errors can cause in case the name of the column is a name of a function or attribute
#
# For better practice its preferred to use the following option

# %%
df.MainBranch
df ['MainBranch']
# Out:
# 0                                            None of these
# 1                           I am a developer by profession
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 73263                       I am a developer by profession
# 73264                       I am a developer by profession
# 73265    I am not primarily a developer, but I write co...
# 73266                       I am a developer by profession
# 73267    I used to be a developer by profession, but no...
# Name: MainBranch, Length: 73268, dtype: object

# %% [markdown]
# To show the content of multiple columns use DataFrame[['','','','']]

# %%
df[['MainBranch','Onboarding']]
# Out:
#                                               MainBranch  Onboarding
# 0                                          None of these         NaN
# 1                         I am a developer by profession         NaN
# 2      I am not primarily a developer, but I write co...         NaN
# 3                         I am a developer by profession         NaN
# 4                         I am a developer by profession         NaN
# ...                                                  ...         ...
# 73263                     I am a developer by profession  Just right
# 73264                     I am a developer by profession   Very long
# 73265  I am not primarily a developer, but I write co...  Just right
# 73266                     I am a developer by profession         NaN
# 73267  I used to be a developer by profession, but no...         NaN
#
# [73268 rows x 2 columns]

# %% [markdown]
# DataFrame.iloc is an integer-location based indexing for selection by position.
# To show the content of a specific row .iloc[] is primarily integer position based (from 0 to length-1 of the axis),
# But may also be used with a Boolean array.

# %%
df.iloc[4]
df.iloc[[4,23]]
# Out:
#     ResponseId                                         MainBranch  \
# 4            5                     I am a developer by profession
# 23          24  I am not primarily a developer, but I write co...
#
#              Employment                            RemoteWork  \
# 4   Employed, full-time  Hybrid (some remote, some in-person)
# 23  Employed, full-time  Hybrid (some remote, some in-person)
#
#                 CodingActivities  \
# 4                          Hobby
# 23  I don’t code outside of work
#
#                                             EdLevel  \
# 4      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                             LearnCode  \
# 4   Other online resources (e.g., videos, blogs, f...
# 23  Other online resources (e.g., videos, blogs, f...
#
#                                       LearnCodeOnline LearnCodeCoursesCert  \
# 4   Technical documentation;Blogs;Stack Overflow;O...                  NaN
# 23  Blogs;Written Tutorials;Stack Overflow;Written...                  NaN
#
#    YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 4          8  ...           NaN           NaN        NaN              NaN
# 23        10  ...           NaN           NaN        NaN              NaN
#
#    TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 4          NaN         NaN         NaN               Too long
# 23         NaN         NaN         NaN  Appropriate in length
#
#                     SurveyEase ConvertedCompYearly
# 4                         Easy                 NaN
# 23  Neither easy nor difficult                 NaN
#
# [2 rows x 79 columns]

# %% [markdown]
# To show a specific column data from several rows

# %%
df.iloc[[0,6],[4,8,9]]
# Out:
#   CodingActivities LearnCodeCoursesCert YearsCode
# 0              NaN                  NaN       NaN
# 6              NaN                  NaN         3

# %% [markdown]
# DataFrame.loc gives Access a group of rows and columns by label(s) or a Boolean array.
# .loc[] is primarily label based, but may also be used with a Boolean array.

# %%
df.loc[[5,15,40],['CompTotal','WebframeHaveWorkedWith','YearsCodePro']]
# Out:
#     CompTotal         WebframeHaveWorkedWith YearsCodePro
# 5         NaN                            NaN          NaN
# 15        NaN  Express;jQuery;Node.js;Vue.js            4
# 40   130000.0   ASP.NET;ASP.NET Core ;jQuery           15

# %% [markdown]
# You can use the python n: and :n to list list of rows till the n

# %%
df.loc[:15,['CompTotal','WebframeHaveWorkedWith','YearsCodePro']]
# Out:
#     CompTotal                             WebframeHaveWorkedWith YearsCodePro
# 0         NaN                                                NaN          NaN
# 1         NaN                                                NaN          NaN
# 2     32000.0                                         Angular.js            5
# 3     60000.0                              ASP.NET;ASP.NET Core            17
# 4         NaN       Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js            3
# 5         NaN                                                NaN          NaN
# 6         NaN     Angular;Next.js;Node.js;React.js;Svelte;Vue.js          NaN
# 7         NaN                                     jQuery;Node.js          NaN
# 8     46000.0                                                NaN            6
# 9         NaN                                                NaN           30
# 10    48000.0                       ASP.NET;ASP.NET Core ;Vue.js            2
# 11   194400.0       ASP.NET;ASP.NET Core ;Express;Node.js;Vue.js           10
# 12    65000.0                                           React.js            5
# 13        NaN  jQuery;Next.js;Node.js;Phoenix;React.js;Ruby o...           15
# 14   110000.0   Django;Flask;jQuery;Node.js;Ruby on Rails;Vue.js            5
# 15        NaN                      Express;jQuery;Node.js;Vue.js            4

# %% [markdown]
# Show a set of rows and columns

# %%
df.loc[5:20,'CodingActivities':'BuyNewTool']
# Out:
#                                      CodingActivities  \
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                        I don’t code outside of work
# 9   Hobby;Contribute to open-source projects;Boots...
# 10                       I don’t code outside of work
# 11  Hobby;Contribute to open-source projects;Freel...
# 12                                              Hobby
# 13                                              Hobby
# 14                      Hobby;Freelance/contract work
# 15           Hobby;Contribute to open-source projects
# 16                                              Hobby
# 17                                              Hobby
# 18                                              Hobby
# 19                                                NaN
# 20                                              Hobby
#
#                                               EdLevel  \
# 5     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6   Secondary school (e.g. American high school, G...
# 7   Some college/university study without earning ...
# 8     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9   Some college/university study without earning ...
# 10       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18  Secondary school (e.g. American high school, G...
# 19  Some college/university study without earning ...
# 20  Some college/university study without earning ...
#
#                                             LearnCode  \
# 5   Books / Physical media;School (i.e., Universit...
# 6   Other online resources (e.g., videos, blogs, f...
# 7                     Online Courses or Certification
# 8                 On the job training;Coding Bootcamp
# 9   Books / Physical media;Other online resources ...
# 10  Books / Physical media;Friend or family member...
# 11  Other online resources (e.g., videos, blogs, f...
# 12            School (i.e., University, College, etc)
# 13  Books / Physical media;School (i.e., Universit...
# 14  Other online resources (e.g., videos, blogs, f...
# 15                             Books / Physical media
# 16  Books / Physical media;Other online resources ...
# 17  Other online resources (e.g., videos, blogs, f...
# 18  Books / Physical media;School (i.e., Universit...
# 19   Books / Physical media;Coding Bootcamp;Colleague
# 20  Books / Physical media;Other online resources ...
#
#                                       LearnCodeOnline  LearnCodeCoursesCert  \
# 5                                                 NaN                   NaN
# 6           Stack Overflow;Video-based Online Courses                   NaN
# 7                                                 NaN        Coursera;Udemy
# 8                                                 NaN                   NaN
# 9   Technical documentation;Blogs;Written Tutorial...                   NaN
# 10  Technical documentation;Blogs;Written Tutorial...                   NaN
# 11  Technical documentation;Blogs;Written Tutorial...                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  Written Tutorials;Stack Overflow;Video-based O...                   NaN
# 15                                                NaN                   NaN
# 16  Technical documentation;Blogs;Written Tutorial...      Udemy;Codecademy
# 17  Technical documentation;Written Tutorials;Stac...  Coursera;Pluralsight
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20  Technical documentation;Blogs;Stack Overflow;V...                   NaN
#
#    YearsCode YearsCodePro                                            DevType  \
# 5         15          NaN                                                NaN
# 6          3          NaN                                                NaN
# 7          1          NaN                      Developer, full-stack;Student
# 8          6            6                                Developer, back-end
# 9         37           30  Developer, desktop or enterprise applications;...
# 10         5            2          Developer, full-stack;Developer, back-end
# 11        12           10                                Engineering manager
# 12        12            5                              Developer, full-stack
# 13        22           15  Developer, front-end;Developer, full-stack;Dev...
# 14        11            5  Developer, full-stack;Academic researcher;DevO...
# 15         4            4                              Developer, full-stack
# 16         7            4                              Developer, full-stack
# 17        13           10                                     Engineer, data
# 18        36           22  Developer, back-end;Developer, desktop or ente...
# 19         2          NaN                                                NaN
# 20         1          NaN                                            Student
#
#                                               OrgSize  \
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                        I don’t know
# 9   Just me - I am a freelancer, sole proprietor, ...
# 10                               100 to 499 employees
# 11                                 20 to 99 employees
# 12                                   2 to 9 employees
# 13                                 20 to 99 employees
# 14                           5,000 to 9,999 employees
# 15  Just me - I am a freelancer, sole proprietor, ...
# 16                                   2 to 9 employees
# 17                           1,000 to 4,999 employees
# 18                               100 to 499 employees
# 19                                                NaN
# 20                                                NaN
#
#                    PurchaseInfluence  \
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8      I have little or no influence
# 9   I have a great deal of influence
# 10     I have little or no influence
# 11             I have some influence
# 12  I have a great deal of influence
# 13             I have some influence
# 14     I have little or no influence
# 15  I have a great deal of influence
# 16             I have some influence
# 17             I have some influence
# 18     I have little or no influence
# 19                               NaN
# 20                               NaN
#
#                                            BuyNewTool
# 5                             Other (please specify):
# 6   Start a free trial;Visit developer communities...
# 7                                  Start a free trial
# 8                                                 NaN
# 9   Start a free trial;Ask developers I know/work ...
# 10  Start a free trial;Visit developer communities...
# 11  Start a free trial;Ask developers I know/work ...
# 12    Visit developer communities like Stack Overflow
# 13  Start a free trial;Ask developers I know/work ...
# 14  Start a free trial;Visit developer communities...
# 15                                 Start a free trial
# 16  Start a free trial;Research companies that hav...
# 17  Start a free trial;Ask developers I know/work ...
# 18  Start a free trial;Visit developer communities...
# 19  Visit developer communities like Stack Overflo...
# 20  Start a free trial;Visit developer communities...

# %% [markdown]
# To return a Series containing counts of unique rows in the DataFrame.

# %%
df['Blockchain'].value_counts()
# Out:
# Indifferent         18331
# Favorable           14629
# Very unfavorable    11625
# Unfavorable         10549
# Unsure               8128
# Very favorable       7809
# Name: Blockchain, dtype: int64

# %% [markdown]
# Set the DataFrame index using existing columns.
# Set the DataFrame index (row labels) using one or more existing columns or arrays (of the correct length).
# The index can replace the existing index or expand on it.

# %%
df.set_index('ResponseId')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5                                         Employed, full-time
# ...                                                       ...
# 73264                                     Employed, full-time
# 73265                                     Employed, full-time
# 73266                                     Employed, full-time
# 73267                                     Employed, full-time
# 73268       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                   Fully remote
# 3           Hybrid (some remote, some in-person)
# 4                                   Fully remote
# 5           Hybrid (some remote, some in-person)
# ...                                          ...
# 73264                               Fully remote
# 73265                             Full in-person
# 73266       Hybrid (some remote, some in-person)
# 73267       Hybrid (some remote, some in-person)
# 73268                               Fully remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2                    Hobby;Contribute to open-source projects
# 3                                                       Hobby
# 4                                I don’t code outside of work
# 5                                                       Hobby
# ...                                                       ...
# 73264                                 Freelance/contract work
# 73265                                                   Hobby
# 73266                           Hobby;School or academic work
# 73267                                                   Hobby
# 73268       Hobby;Contribute to open-source projects;Boots...
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 73264          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73265       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73266          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73268          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Books / Physical media;Friend or family member...
# 4           Books / Physical media;School (i.e., Universit...
# 5           Other online resources (e.g., videos, blogs, f...
# ...                                                       ...
# 73264       Books / Physical media;Other online resources ...
# 73265       Other online resources (e.g., videos, blogs, f...
# 73266       Books / Physical media;Other online resources ...
# 73267              Books / Physical media;On the job training
# 73268       Books / Physical media;Friend or family member...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Technical documentation;Blogs;Programming Game...
# 4                                                         NaN
# 5           Technical documentation;Blogs;Stack Overflow;O...
# ...                                                       ...
# 73264       Technical documentation;Blogs;Written Tutorial...
# 73265       Technical documentation;Blogs;Written Tutorial...
# 73266       Technical documentation;Programming Games;Stac...
# 73267                                                     NaN
# 73268       Technical documentation;Blogs;Programming Game...
#
#                         LearnCodeCoursesCert YearsCode YearsCodePro  ...  \
# ResponseId                                                           ...
# 1                                        NaN       NaN          NaN  ...
# 2                                        NaN       NaN          NaN  ...
# 3                                        NaN        14            5  ...
# 4                                        NaN        20           17  ...
# 5                                        NaN         8            3  ...
# ...                                      ...       ...          ...  ...
# 73264                                  Udemy         8            5  ...
# 73265                 Coursera;Udemy;Udacity         6            5  ...
# 73266       Udemy;Codecademy;Pluralsight;edX        42           33  ...
# 73267                                    NaN        50           31  ...
# 73268                      Udemy;Pluralsight        16            5  ...
#
#                   TimeSearching               TimeAnswering  Onboarding  \
# ResponseId
# 1                           NaN                         NaN         NaN
# 2                           NaN                         NaN         NaN
# 3                           NaN                         NaN         NaN
# 4                           NaN                         NaN         NaN
# 5                           NaN                         NaN         NaN
# ...                         ...                         ...         ...
# 73264       30-60 minutes a day  Less than 15 minutes a day  Just right
# 73265       15-30 minutes a day        60-120 minutes a day   Very long
# 73266       30-60 minutes a day        60-120 minutes a day  Just right
# 73267                       NaN                         NaN         NaN
# 73268                       NaN                         NaN         NaN
#
#                                              ProfessionalTech TrueFalse_1  \
# ResponseId
# 1                                                         NaN         NaN
# 2                                                         NaN         NaN
# 3                                                         NaN         NaN
# 4                                                         NaN         NaN
# 5                                                         NaN         NaN
# ...                                                       ...         ...
# 73264       DevOps function;Microservices;Developer portal...         Yes
# 73265                                           None of these          No
# 73266                                           None of these          No
# 73267                                                     NaN         NaN
# 73268                                                     NaN         NaN
#
#            TrueFalse_2  TrueFalse_3           SurveyLength  \
# ResponseId
# 1                  NaN          NaN                    NaN
# 2                  NaN          NaN               Too long
# 3                  NaN          NaN  Appropriate in length
# 4                  NaN          NaN  Appropriate in length
# 5                  NaN          NaN               Too long
# ...                ...          ...                    ...
# 73264              Yes          Yes               Too long
# 73265              Yes          Yes               Too long
# 73266               No           No  Appropriate in length
# 73267              NaN          NaN  Appropriate in length
# 73268              NaN          NaN  Appropriate in length
#
#                             SurveyEase ConvertedCompYearly
# ResponseId
# 1                                  NaN                 NaN
# 2                            Difficult                 NaN
# 3           Neither easy nor difficult             40205.0
# 4                                 Easy            215232.0
# 5                                 Easy                 NaN
# ...                                ...                 ...
# 73264                             Easy                 NaN
# 73265                             Easy                 NaN
# 73266                             Easy                 NaN
# 73267                             Easy                 NaN
# 73268                             Easy                 NaN
#
# [73268 rows x 78 columns]

# %% [markdown]
# To move the indexed column to the 1st position (to the left), this will modify the original table

# %%
df.set_index('ResponseId', inplace=True)

# %% [markdown]
# Reset the index, or a level of it.
# Reset the index of the DataFrame and use the default one instead.
# If the DataFrame has a MultiIndex, this method can remove one or more levels.

# %%
df.reset_index (inplace=True)

# %% [markdown]
# To set an index for a column during the data upload
#
# df = pd.read_csv(body, index_col = 'Respondent')

# %% [markdown]
# Sort object by labels (along an axis).
# Returns a new DataFrame sorted by label if inplace argument is False,otherwise updates the original DataFrame and returns None.

# %%
df.sort_index()
# Out:
#        index  ResponseId                                         MainBranch  \
# 0          0           1                                      None of these
# 1          1           2                     I am a developer by profession
# 2          2           3  I am not primarily a developer, but I write co...
# 3          3           4                     I am a developer by profession
# 4          4           5                     I am a developer by profession
# ...      ...         ...                                                ...
# 73263  73263       73264                     I am a developer by profession
# 73264  73264       73265                     I am a developer by profession
# 73265  73265       73266  I am not primarily a developer, but I write co...
# 73266  73266       73267                     I am a developer by profession
# 73267  73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert  ...        TimeSearching  \
# 0                                   NaN  ...                  NaN
# 1                                   NaN  ...                  NaN
# 2                                   NaN  ...                  NaN
# 3                                   NaN  ...                  NaN
# 4                                   NaN  ...                  NaN
# ...                                 ...  ...                  ...
# 73263                             Udemy  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX  ...  30-60 minutes a day
# 73266                               NaN  ...                  NaN
# 73267                 Udemy;Pluralsight  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 80 columns]

# %% [markdown]
# To create a filter

# %%
myfilter = df['Country'] == 'Israel'
df[myfilter]
# Out:
#        index  ResponseId                                         MainBranch  \
# 3          3           4                     I am a developer by profession
# 24        24          25                     I am a developer by profession
# 27        27          28                     I am a developer by profession
# 33        33          34  I am not primarily a developer, but I write co...
# 35        35          36  I am not primarily a developer, but I write co...
# ...      ...         ...                                                ...
# 72830  72830       72831                     I am a developer by profession
# 72961  72961       72962                     I am a developer by profession
# 73001  73001       73002                     I am a developer by profession
# 73011  73011       73012                     I am a developer by profession
# 73238  73238       73239                     I am a developer by profession
#
#                                               Employment  \
# 3                                    Employed, full-time
# 24     Independent contractor, freelancer, or self-em...
# 27                Not employed, and not looking for work
# 33                Student, part-time;Employed, part-time
# 35                                    Student, full-time
# ...                                                  ...
# 72830                                Employed, full-time
# 72961                                Employed, full-time
# 73001                                Employed, full-time
# 73011                                Employed, full-time
# 73238                                Employed, full-time
#
#                                  RemoteWork                CodingActivities  \
# 3                              Fully remote    I don’t code outside of work
# 24                             Fully remote    I don’t code outside of work
# 27                                      NaN                             NaN
# 33                           Full in-person                           Hobby
# 35                                      NaN                             NaN
# ...                                     ...                             ...
# 72830                        Full in-person         Other (please specify):
# 72961  Hybrid (some remote, some in-person)    I don’t code outside of work
# 73001  Hybrid (some remote, some in-person)  Hobby;Bootstrapping a business
# 73011                        Full in-person                           Hobby
# 73238  Hybrid (some remote, some in-person)    I don’t code outside of work
#
#                                                  EdLevel  \
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24     Some college/university study without earning ...
# 27                                        Something else
# 33     Some college/university study without earning ...
# 35            Other doctoral degree (Ph.D., Ed.D., etc.)
# ...                                                  ...
# 72830    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72961       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73001                          Primary/elementary school
# 73011       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73238  Some college/university study without earning ...
#
#                                                LearnCode  \
# 3      Books / Physical media;School (i.e., Universit...
# 24                                                   NaN
# 27     Other online resources (e.g., videos, blogs, f...
# 33     Friend or family member;Other online resources...
# 35     Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 72830  Other online resources (e.g., videos, blogs, f...
# 72961  School (i.e., University, College, etc);On the...
# 73001  Books / Physical media;Friend or family member...
# 73011  Books / Physical media;Other online resources ...
# 73238  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  \
# 3                                                    NaN
# 24                                                   NaN
# 27     Technical documentation;Written Tutorials;Stac...
# 33     Technical documentation;Blogs;Written Tutorial...
# 35     Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 72830  Technical documentation;Blogs;Stack Overflow;H...
# 72961                                                NaN
# 73001                                                NaN
# 73011  Technical documentation;Blogs;Stack Overflow;O...
# 73238  Technical documentation;Blogs;Written Tutorial...
#
#            LearnCodeCoursesCert  ...         TimeSearching  \
# 3                           NaN  ...                   NaN
# 24                          NaN  ...                   NaN
# 27                          NaN  ...                   NaN
# 33                          NaN  ...                   NaN
# 35                          NaN  ...                   NaN
# ...                         ...  ...                   ...
# 72830                       NaN  ...  60-120 minutes a day
# 72961                       NaN  ...   30-60 minutes a day
# 73001                     Other  ...                   NaN
# 73011         Udemy;Pluralsight  ...  60-120 minutes a day
# 73238  Udemy;Codecademy;Udacity  ...   30-60 minutes a day
#
#               TimeAnswering      Onboarding  \
# 3                       NaN             NaN
# 24                      NaN             NaN
# 27                      NaN             NaN
# 33                      NaN             NaN
# 35                      NaN             NaN
# ...                     ...             ...
# 72830   15-30 minutes a day  Somewhat short
# 72961   30-60 minutes a day      Just right
# 73001                   NaN             NaN
# 73011  60-120 minutes a day  Somewhat short
# 73238  60-120 minutes a day   Somewhat long
#
#                                         ProfessionalTech TrueFalse_1  \
# 3                                                    NaN         NaN
# 24                                                   NaN         NaN
# 27                                                   NaN         NaN
# 33                                                   NaN         NaN
# 35                                                   NaN         NaN
# ...                                                  ...         ...
# 72830                                                NaN         Yes
# 72961  Innersource initiative;DevOps function;Microse...         Yes
# 73001                                                NaN         NaN
# 73011             Innersource initiative;DevOps function          No
# 73238  DevOps function;Microservices;Developer portal...         Yes
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 3             NaN         NaN  Appropriate in length
# 24            NaN         NaN              Too short
# 27            NaN         NaN  Appropriate in length
# 33            NaN         NaN  Appropriate in length
# 35            NaN         NaN  Appropriate in length
# ...           ...         ...                    ...
# 72830          No          No               Too long
# 72961         Yes         Yes  Appropriate in length
# 73001         NaN         NaN  Appropriate in length
# 73011         Yes         Yes  Appropriate in length
# 73238         Yes         Yes  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 3                            Easy            215232.0
# 24                           Easy                 NaN
# 27                           Easy                 NaN
# 33                           Easy                 NaN
# 35     Neither easy nor difficult                 NaN
# ...                           ...                 ...
# 72830  Neither easy nor difficult             75324.0
# 72961  Neither easy nor difficult            283982.0
# 73001                        Easy            215232.0
# 73011  Neither easy nor difficult             63852.0
# 73238                        Easy                 NaN
#
# [795 rows x 80 columns]

# %% [markdown]
# To find a specific column data from the filter

# %%
df.loc[myfilter, 'Employment']
# Out:
# 3                                      Employed, full-time
# 24       Independent contractor, freelancer, or self-em...
# 27                  Not employed, and not looking for work
# 33                  Student, part-time;Employed, part-time
# 35                                      Student, full-time
#                                ...
# 72830                                  Employed, full-time
# 72961                                  Employed, full-time
# 73001                                  Employed, full-time
# 73011                                  Employed, full-time
# 73238                                  Employed, full-time
# Name: Employment, Length: 795, dtype: object

# %% [markdown]
# & (and) | (or) operators can expand the filter command

# %%
myfilter = (df['Country'] == 'Israel') & (df['Gender'] == 'Woman')
df[myfilter]
# Out:
#        index  ResponseId                                         MainBranch  \
# 138      138         139                     I am a developer by profession
# 189      189         190                     I am a developer by profession
# 275      275         276                     I am a developer by profession
# 1757    1757        1758                     I am a developer by profession
# 2161    2161        2162                     I am a developer by profession
# 3810    3810        3811                     I am a developer by profession
# 4207    4207        4208                     I am a developer by profession
# 8069    8069        8070  I am not primarily a developer, but I write co...
# 14992  14992       14993                              I am learning to code
# 15125  15125       15126                     I am a developer by profession
# 17243  17243       17244                     I am a developer by profession
# 17907  17907       17908                     I am a developer by profession
# 19554  19554       19555  I used to be a developer by profession, but no...
# 20105  20105       20106                     I am a developer by profession
# 24112  24112       24113                     I am a developer by profession
# 24645  24645       24646                        I code primarily as a hobby
# 25585  25585       25586                     I am a developer by profession
# 27418  27418       27419                     I am a developer by profession
# 28330  28330       28331                     I am a developer by profession
# 29286  29286       29287                     I am a developer by profession
# 32091  32091       32092                     I am a developer by profession
# 34723  34723       34724                     I am a developer by profession
# 34845  34845       34846                     I am a developer by profession
# 35586  35586       35587                        I code primarily as a hobby
# 36340  36340       36341                     I am a developer by profession
# 38372  38372       38373                     I am a developer by profession
# 43272  43272       43273                              I am learning to code
# 44694  44694       44695                     I am a developer by profession
# 48239  48239       48240                     I am a developer by profession
# 48478  48478       48479                     I am a developer by profession
# 52060  52060       52061                        I code primarily as a hobby
# 55642  55642       55643                     I am a developer by profession
# 55757  55757       55758  I am not primarily a developer, but I write co...
# 56060  56060       56061                     I am a developer by profession
# 57377  57377       57378                     I am a developer by profession
# 57591  57591       57592                     I am a developer by profession
# 58079  58079       58080                     I am a developer by profession
# 62601  62601       62602                     I am a developer by profession
# 62609  62609       62610                     I am a developer by profession
# 62902  62902       62903                     I am a developer by profession
# 62955  62955       62956                     I am a developer by profession
# 69966  69966       69967                     I am a developer by profession
# 70005  70005       70006                     I am a developer by profession
# 70422  70422       70423                     I am a developer by profession
# 70739  70739       70740                     I am a developer by profession
# 72545  72545       72546                     I am a developer by profession
# 73238  73238       73239                     I am a developer by profession
#
#                                               Employment  \
# 138                                  Employed, full-time
# 189                                  Employed, full-time
# 275                                  Employed, full-time
# 1757                                 Employed, full-time
# 2161   Employed, full-time;Independent contractor, fr...
# 3810                                 Employed, full-time
# 4207                                 Employed, full-time
# 8069                                 Employed, full-time
# 14992                                 Student, full-time
# 15125                                Employed, full-time
# 17243  Independent contractor, freelancer, or self-em...
# 17907                                Employed, full-time
# 19554  Student, part-time;Not employed, and not looki...
# 20105                                Employed, full-time
# 24112                                Employed, full-time
# 24645                                 Student, full-time
# 25585                 Not employed, but looking for work
# 27418                                 Student, part-time
# 28330                                Employed, full-time
# 29286                                Employed, full-time
# 32091                                Employed, full-time
# 34723                                Employed, full-time
# 34845                                Employed, full-time
# 35586                                Employed, full-time
# 36340                                Employed, full-time
# 38372                                Employed, full-time
# 43272                                Employed, full-time
# 44694  Student, part-time;Independent contractor, fre...
# 48239                                Employed, full-time
# 48478                                Employed, full-time
# 52060                                Employed, full-time
# 55642                                Employed, full-time
# 55757                                Employed, part-time
# 56060                                Employed, full-time
# 57377             Student, full-time;Employed, part-time
# 57591                                Employed, full-time
# 58079                                Employed, full-time
# 62601                                Employed, full-time
# 62609                                Employed, full-time
# 62902                                Employed, full-time
# 62955                                Employed, full-time
# 69966                                Employed, full-time
# 70005                                Employed, part-time
# 70422                                 Student, full-time
# 70739                                Employed, full-time
# 72545                                Employed, full-time
# 73238                                Employed, full-time
#
#                                  RemoteWork  \
# 138    Hybrid (some remote, some in-person)
# 189                            Fully remote
# 275                            Fully remote
# 1757   Hybrid (some remote, some in-person)
# 2161                         Full in-person
# 3810   Hybrid (some remote, some in-person)
# 4207   Hybrid (some remote, some in-person)
# 8069                           Fully remote
# 14992                                   NaN
# 15125  Hybrid (some remote, some in-person)
# 17243                          Fully remote
# 17907  Hybrid (some remote, some in-person)
# 19554                                   NaN
# 20105  Hybrid (some remote, some in-person)
# 24112                        Full in-person
# 24645                                   NaN
# 25585                                   NaN
# 27418                                   NaN
# 28330  Hybrid (some remote, some in-person)
# 29286                          Fully remote
# 32091  Hybrid (some remote, some in-person)
# 34723  Hybrid (some remote, some in-person)
# 34845  Hybrid (some remote, some in-person)
# 35586                        Full in-person
# 36340                        Full in-person
# 38372  Hybrid (some remote, some in-person)
# 43272                        Full in-person
# 44694                          Fully remote
# 48239  Hybrid (some remote, some in-person)
# 48478  Hybrid (some remote, some in-person)
# 52060                        Full in-person
# 55642  Hybrid (some remote, some in-person)
# 55757  Hybrid (some remote, some in-person)
# 56060  Hybrid (some remote, some in-person)
# 57377                        Full in-person
# 57591                          Fully remote
# 58079                          Fully remote
# 62601  Hybrid (some remote, some in-person)
# 62609  Hybrid (some remote, some in-person)
# 62902  Hybrid (some remote, some in-person)
# 62955  Hybrid (some remote, some in-person)
# 69966  Hybrid (some remote, some in-person)
# 70005                          Fully remote
# 70422                                   NaN
# 70739                        Full in-person
# 72545  Hybrid (some remote, some in-person)
# 73238  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 138                                                Hobby
# 189                         I don’t code outside of work
# 275                                                Hobby
# 1757                                               Hobby
# 2161                        I don’t code outside of work
# 3810                                               Hobby
# 4207                        I don’t code outside of work
# 8069                                               Hobby
# 14992                                                NaN
# 15125           Hobby;Contribute to open-source projects
# 17243                                              Hobby
# 17907                            School or academic work
# 19554                                                NaN
# 20105  Hobby;Contribute to open-source projects;Boots...
# 24112                                              Hobby
# 24645                                                NaN
# 25585                                                NaN
# 27418                                                NaN
# 28330                       I don’t code outside of work
# 29286                                              Hobby
# 32091                     Hobby;Bootstrapping a business
# 34723                            Other (please specify):
# 34845                       I don’t code outside of work
# 35586                                              Hobby
# 36340                       I don’t code outside of work
# 38372                       I don’t code outside of work
# 43272           Hobby;Contribute to open-source projects
# 44694           Hobby;Contribute to open-source projects
# 48239                            Other (please specify):
# 48478                            School or academic work
# 52060                 Contribute to open-source projects
# 55642                                              Hobby
# 55757                      Hobby;School or academic work
# 56060                       I don’t code outside of work
# 57377                            School or academic work
# 57591                      Hobby;Freelance/contract work
# 58079                       I don’t code outside of work
# 62601                                              Hobby
# 62609                            School or academic work
# 62902                            School or academic work
# 62955                                              Hobby
# 69966                                              Hobby
# 70005                       I don’t code outside of work
# 70422                                                NaN
# 70739                                              Hobby
# 72545                       I don’t code outside of work
# 73238                       I don’t code outside of work
#
#                                                  EdLevel  \
# 138         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 189         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 275    Secondary school (e.g. American high school, G...
# 1757        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2161   Secondary school (e.g. American high school, G...
# 3810        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4207   Secondary school (e.g. American high school, G...
# 8069   Some college/university study without earning ...
# 14992       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15125       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17243  Secondary school (e.g. American high school, G...
# 17907       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19554  Some college/university study without earning ...
# 20105                Associate degree (A.A., A.S., etc.)
# 24112       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24645                          Primary/elementary school
# 25585  Some college/university study without earning ...
# 27418  Secondary school (e.g. American high school, G...
# 28330  Some college/university study without earning ...
# 29286  Some college/university study without earning ...
# 32091  Some college/university study without earning ...
# 34723       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34845       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35586       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36340  Some college/university study without earning ...
# 38372       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43272  Some college/university study without earning ...
# 44694       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48239         Other doctoral degree (Ph.D., Ed.D., etc.)
# 48478       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 52060  Secondary school (e.g. American high school, G...
# 55642       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 55757                          Primary/elementary school
# 56060       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57377       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57591       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58079                Associate degree (A.A., A.S., etc.)
# 62601       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62609         Other doctoral degree (Ph.D., Ed.D., etc.)
# 62902    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 62955  Some college/university study without earning ...
# 69966       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 70005    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 70422  Some college/university study without earning ...
# 70739       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72545    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73238  Some college/university study without earning ...
#
#                                                LearnCode  \
# 138    Other online resources (e.g., videos, blogs, f...
# 189    Other online resources (e.g., videos, blogs, f...
# 275    Other online resources (e.g., videos, blogs, f...
# 1757             School (i.e., University, College, etc)
# 2161   Other online resources (e.g., videos, blogs, f...
# 3810   Books / Physical media;Other online resources ...
# 4207   Books / Physical media;Other online resources ...
# 8069   School (i.e., University, College, etc);On the...
# 14992  Books / Physical media;Friend or family member...
# 15125  Books / Physical media;Friend or family member...
# 17243  Books / Physical media;Other online resources ...
# 17907  Other online resources (e.g., videos, blogs, f...
# 19554  School (i.e., University, College, etc);On the...
# 20105  Books / Physical media;On the job training;Onl...
# 24112  Books / Physical media;School (i.e., Universit...
# 24645  Books / Physical media;Other online resources ...
# 25585            School (i.e., University, College, etc)
# 27418  Books / Physical media;Other online resources ...
# 28330  School (i.e., University, College, etc);On the...
# 29286                                          Colleague
# 32091  Other online resources (e.g., videos, blogs, f...
# 34723            School (i.e., University, College, etc)
# 34845  Books / Physical media;Other online resources ...
# 35586  Other online resources (e.g., videos, blogs, f...
# 36340  Other online resources (e.g., videos, blogs, f...
# 38372            School (i.e., University, College, etc)
# 43272  Friend or family member;Other online resources...
# 44694  Books / Physical media;School (i.e., Universit...
# 48239  Friend or family member;Other online resources...
# 48478  Books / Physical media;Other online resources ...
# 52060  Books / Physical media;Online Courses or Certi...
# 55642  Books / Physical media;School (i.e., Universit...
# 55757  Friend or family member;Other online resources...
# 56060  Other online resources (e.g., videos, blogs, f...
# 57377            School (i.e., University, College, etc)
# 57591    Online Courses or Certification;Coding Bootcamp
# 58079  Other online resources (e.g., videos, blogs, f...
# 62601  Books / Physical media;Other online resources ...
# 62609  Books / Physical media;School (i.e., Universit...
# 62902  Books / Physical media;Other online resources ...
# 62955  Books / Physical media;Other online resources ...
# 69966  Books / Physical media;Other online resources ...
# 70005            School (i.e., University, College, etc)
# 70422  Other online resources (e.g., videos, blogs, f...
# 70739            School (i.e., University, College, etc)
# 72545  Books / Physical media;Other online resources ...
# 73238  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  \
# 138    Technical documentation;Blogs;Stack Overflow;H...
# 189      Blogs;Stack Overflow;Video-based Online Courses
# 275    Technical documentation;Blogs;Stack Overflow;O...
# 1757                                                 NaN
# 2161   Technical documentation;Blogs;Written Tutorial...
# 3810   Technical documentation;Blogs;Stack Overflow;O...
# 4207   Technical documentation;Blogs;Written Tutorial...
# 8069                                                 NaN
# 14992  Technical documentation;Blogs;Written Tutorial...
# 15125  Technical documentation;Blogs;Programming Game...
# 17243  Technical documentation;Blogs;Written Tutorial...
# 17907  Technical documentation;Blogs;Written Tutorial...
# 19554                                                NaN
# 20105                                                NaN
# 24112                                                NaN
# 24645  Technical documentation;Stack Overflow;How-to ...
# 25585                                                NaN
# 27418  Technical documentation;Written Tutorials;Stac...
# 28330                                                NaN
# 29286                                                NaN
# 32091  Technical documentation;Stack Overflow;Online ...
# 34723                                                NaN
# 34845  Technical documentation;Written Tutorials;Onli...
# 35586  Technical documentation;Written Tutorials;Stac...
# 36340                                  Written Tutorials
# 38372                                                NaN
# 43272  Technical documentation;Blogs;Written Tutorial...
# 44694                                                NaN
# 48239  Stack Overflow;Video-based Online Courses;How-...
# 48478  Technical documentation;Blogs;Written Tutorial...
# 52060                                                NaN
# 55642                                                NaN
# 55757  Online books;Video-based Online Courses;Writte...
# 56060  Technical documentation;Blogs;Written Tutorial...
# 57377                                                NaN
# 57591                                                NaN
# 58079                      Technical documentation;Blogs
# 62601  Technical documentation;Blogs;Written Tutorial...
# 62609                                                NaN
# 62902  Stack Overflow;Video-based Online Courses;Onli...
# 62955  Technical documentation;Blogs;Stack Overflow;O...
# 69966  Technical documentation;Blogs;Video-based Onli...
# 70005                                                NaN
# 70422  Technical documentation;Video-based Online Cou...
# 70739                                                NaN
# 72545  Technical documentation;Written Tutorials;Stac...
# 73238  Technical documentation;Blogs;Written Tutorial...
#
#                                 LearnCodeCoursesCert  ...  \
# 138                                              NaN  ...
# 189                                              edX  ...
# 275                                              NaN  ...
# 1757                                             NaN  ...
# 2161                          Udemy;Codecademy;Other  ...
# 3810                                  Coursera;Udemy  ...
# 4207                                    Coursera;edX  ...
# 8069                                             NaN  ...
# 14992                                       Coursera  ...
# 15125        Coursera;Udemy;Codecademy;Udacity;Other  ...
# 17243                                          Udemy  ...
# 17907                                            NaN  ...
# 19554                                            NaN  ...
# 20105                                       Coursera  ...
# 24112                                            NaN  ...
# 24645                                            NaN  ...
# 25585                                            NaN  ...
# 27418                                 Coursera;Udemy  ...
# 28330                                          Other  ...
# 29286                                            NaN  ...
# 32091                        Udemy;Pluralsight;Other  ...
# 34723                                            NaN  ...
# 34845                                            NaN  ...
# 35586                  Coursera;Udemy;Codecademy;edX  ...
# 36340                                            NaN  ...
# 38372                                            NaN  ...
# 43272                                            NaN  ...
# 44694                                          Udemy  ...
# 48239                               Coursera;Udacity  ...
# 48478                                 Coursera;Udemy  ...
# 52060                                            edX  ...
# 55642                                          Udemy  ...
# 55757          Coursera;Udemy;Codecademy;Pluralsight  ...
# 56060                                            NaN  ...
# 57377                                            NaN  ...
# 57591  Coursera;Udemy;Codecademy;Pluralsight;Udacity  ...
# 58079                                          Udemy  ...
# 62601                                 Coursera;Udemy  ...
# 62609                             Coursera;Udemy;edX  ...
# 62902  Coursera;Udemy;Codecademy;Pluralsight;Udacity  ...
# 62955                                            NaN  ...
# 69966                                            NaN  ...
# 70005                                            NaN  ...
# 70422                                       Coursera  ...
# 70739                                            NaN  ...
# 72545                                            NaN  ...
# 73238                       Udemy;Codecademy;Udacity  ...
#
#                     TimeSearching               TimeAnswering      Onboarding  \
# 138           30-60 minutes a day         15-30 minutes a day       Very long
# 189          60-120 minutes a day         15-30 minutes a day             NaN
# 275          60-120 minutes a day         15-30 minutes a day      Very short
# 1757         60-120 minutes a day      Over 120 minutes a day      Just right
# 2161                          NaN                         NaN             NaN
# 3810          15-30 minutes a day        60-120 minutes a day  Somewhat short
# 4207          30-60 minutes a day         15-30 minutes a day      Just right
# 8069       Over 120 minutes a day  Less than 15 minutes a day   Somewhat long
# 14992                         NaN                         NaN             NaN
# 15125        60-120 minutes a day         15-30 minutes a day      Just right
# 17243                         NaN                         NaN             NaN
# 17907                         NaN                         NaN             NaN
# 19554                         NaN                         NaN             NaN
# 20105        60-120 minutes a day         15-30 minutes a day  Somewhat short
# 24112         15-30 minutes a day         15-30 minutes a day   Somewhat long
# 24645                         NaN                         NaN             NaN
# 25585                         NaN                         NaN             NaN
# 27418                         NaN                         NaN             NaN
# 28330      Over 120 minutes a day         15-30 minutes a day   Somewhat long
# 29286                         NaN                         NaN             NaN
# 32091                         NaN                         NaN             NaN
# 34723         30-60 minutes a day         15-30 minutes a day   Somewhat long
# 34845        60-120 minutes a day      Over 120 minutes a day   Somewhat long
# 35586                         NaN                         NaN             NaN
# 36340         15-30 minutes a day         15-30 minutes a day   Somewhat long
# 38372         30-60 minutes a day         30-60 minutes a day   Somewhat long
# 43272         15-30 minutes a day         30-60 minutes a day   Somewhat long
# 44694                         NaN                         NaN             NaN
# 48239                         NaN                         NaN             NaN
# 48478      Over 120 minutes a day      Over 120 minutes a day   Somewhat long
# 52060         15-30 minutes a day  Less than 15 minutes a day      Just right
# 55642        60-120 minutes a day         30-60 minutes a day      Just right
# 55757                         NaN                         NaN             NaN
# 56060         15-30 minutes a day         15-30 minutes a day   Somewhat long
# 57377                         NaN                         NaN             NaN
# 57591         30-60 minutes a day         15-30 minutes a day   Somewhat long
# 58079                         NaN                         NaN             NaN
# 62601         15-30 minutes a day         30-60 minutes a day      Just right
# 62609                         NaN                         NaN             NaN
# 62902         30-60 minutes a day         30-60 minutes a day      Just right
# 62955         30-60 minutes a day        60-120 minutes a day   Somewhat long
# 69966         15-30 minutes a day         15-30 minutes a day   Somewhat long
# 70005         30-60 minutes a day  Less than 15 minutes a day      Just right
# 70422                         NaN                         NaN             NaN
# 70739  Less than 15 minutes a day         30-60 minutes a day      Just right
# 72545         15-30 minutes a day         30-60 minutes a day             NaN
# 73238         30-60 minutes a day        60-120 minutes a day   Somewhat long
#
#                                         ProfessionalTech TrueFalse_1  \
# 138    Developer portal or other central places to fi...          No
# 189    DevOps function;Microservices;Continuous integ...          No
# 275    Innersource initiative;DevOps function;Microse...          No
# 1757   Innersource initiative;DevOps function;Automat...          No
# 2161                                                 NaN         NaN
# 3810   DevOps function;Microservices;Developer portal...         Yes
# 4207   Innersource initiative;DevOps function;Microse...         Yes
# 8069                                       None of these          No
# 14992                                                NaN         NaN
# 15125              Automated testing;Observability tools         Yes
# 17243                                                NaN         NaN
# 17907                                                NaN         NaN
# 19554                                                NaN         NaN
# 20105  DevOps function;Microservices;Developer portal...         Yes
# 24112  DevOps function;Microservices;Continuous integ...         Yes
# 24645                                                NaN         NaN
# 25585                                                NaN         NaN
# 27418                                                NaN         NaN
# 28330                                      None of these         Yes
# 29286                                                NaN         NaN
# 32091                                                NaN         NaN
# 34723  DevOps function;Microservices;Developer portal...          No
# 34845  Innersource initiative;DevOps function;Microse...         Yes
# 35586                                                NaN         NaN
# 36340                                      None of these         Yes
# 38372  DevOps function;Microservices;Developer portal...         Yes
# 43272                                                NaN         Yes
# 44694                                                NaN         NaN
# 48239                                                NaN         NaN
# 48478  Microservices;Continuous integration (CI) and ...         Yes
# 52060                                      None of these         Yes
# 55642  DevOps function;Microservices;Continuous integ...          No
# 55757                                                NaN         NaN
# 56060  DevOps function;Developer portal or other cent...          No
# 57377                                                NaN         NaN
# 57591  DevOps function;Developer portal or other cent...          No
# 58079                                                NaN         NaN
# 62601  Innersource initiative;DevOps function;Microse...         Yes
# 62609                                                NaN         NaN
# 62902  Innersource initiative;DevOps function;Microse...          No
# 62955  DevOps function;Microservices;Developer portal...         Yes
# 69966  DevOps function;Microservices;Developer portal...         Yes
# 70005  DevOps function;Developer portal or other cent...          No
# 70422                                                NaN         NaN
# 70739                                    DevOps function         Yes
# 72545                                                NaN         Yes
# 73238  DevOps function;Microservices;Developer portal...         Yes
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 138           Yes         Yes               Too long
# 189            No          No               Too long
# 275            No          No  Appropriate in length
# 1757          Yes         Yes               Too long
# 2161          NaN         NaN               Too long
# 3810           No         Yes  Appropriate in length
# 4207          Yes         Yes               Too long
# 8069           No         Yes  Appropriate in length
# 14992         NaN         NaN               Too long
# 15125         Yes         Yes               Too long
# 17243         NaN         NaN  Appropriate in length
# 17907         NaN         NaN  Appropriate in length
# 19554         NaN         NaN  Appropriate in length
# 20105          No         Yes  Appropriate in length
# 24112          No         Yes               Too long
# 24645         NaN         NaN               Too long
# 25585         NaN         NaN               Too long
# 27418         NaN         NaN  Appropriate in length
# 28330         Yes         Yes               Too long
# 29286         NaN         NaN               Too long
# 32091         NaN         NaN                    NaN
# 34723          No         Yes  Appropriate in length
# 34845         Yes         Yes  Appropriate in length
# 35586         NaN         NaN               Too long
# 36340          No          No  Appropriate in length
# 38372         Yes         Yes  Appropriate in length
# 43272         Yes         Yes  Appropriate in length
# 44694         NaN         NaN  Appropriate in length
# 48239         NaN         NaN  Appropriate in length
# 48478          No          No  Appropriate in length
# 52060         Yes         Yes  Appropriate in length
# 55642          No         Yes  Appropriate in length
# 55757         NaN         NaN               Too long
# 56060          No         Yes  Appropriate in length
# 57377         NaN         NaN               Too long
# 57591         Yes          No  Appropriate in length
# 58079         NaN         NaN  Appropriate in length
# 62601         Yes          No               Too long
# 62609         NaN         NaN  Appropriate in length
# 62902         Yes         Yes  Appropriate in length
# 62955         Yes         Yes  Appropriate in length
# 69966         Yes         Yes  Appropriate in length
# 70005          No         Yes  Appropriate in length
# 70422         NaN         NaN               Too long
# 70739          No         Yes  Appropriate in length
# 72545          No         Yes  Appropriate in length
# 73238         Yes         Yes  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 138                          Easy            197292.0
# 189    Neither easy nor difficult                 NaN
# 275                          Easy             96852.0
# 1757   Neither easy nor difficult            115500.0
# 2161                         Easy                 NaN
# 3810                         Easy            125544.0
# 4207   Neither easy nor difficult            121968.0
# 8069   Neither easy nor difficult             62200.0
# 14992  Neither easy nor difficult                 NaN
# 15125  Neither easy nor difficult                 NaN
# 17243                        Easy                 NaN
# 17907                        Easy            114792.0
# 19554  Neither easy nor difficult                 NaN
# 20105                        Easy            143484.0
# 24112                        Easy            161424.0
# 24645                        Easy                 NaN
# 25585  Neither easy nor difficult                 NaN
# 27418                        Easy                 NaN
# 28330                   Difficult             35868.0
# 29286  Neither easy nor difficult             37668.0
# 32091                         NaN                 NaN
# 34723                        Easy             78912.0
# 34845  Neither easy nor difficult            100440.0
# 35586                        Easy                 NaN
# 36340  Neither easy nor difficult             86088.0
# 38372  Neither easy nor difficult            136308.0
# 43272  Neither easy nor difficult                 NaN
# 44694  Neither easy nor difficult                 NaN
# 48239                        Easy            225984.0
# 48478  Neither easy nor difficult            140496.0
# 52060                   Difficult                 NaN
# 55642                        Easy            132720.0
# 55757  Neither easy nor difficult                 NaN
# 56060  Neither easy nor difficult                 NaN
# 57377                        Easy                 NaN
# 57591                        Easy            138288.0
# 58079                        Easy             68160.0
# 62601  Neither easy nor difficult                 NaN
# 62609  Neither easy nor difficult                 NaN
# 62902  Neither easy nor difficult                 NaN
# 62955                        Easy             96852.0
# 69966                        Easy            161424.0
# 70005                        Easy                 NaN
# 70422                        Easy                 NaN
# 70739                        Easy                 NaN
# 72545  Neither easy nor difficult            105013.0
# 73238                        Easy                 NaN
#
# [47 rows x 80 columns]

# %% [markdown]
# To get the reversed answer of the filter

# %%
df.loc[~myfilter]
# Out:
#        index  ResponseId                                         MainBranch  \
# 0          0           1                                      None of these
# 1          1           2                     I am a developer by profession
# 2          2           3  I am not primarily a developer, but I write co...
# 3          3           4                     I am a developer by profession
# 4          4           5                     I am a developer by profession
# ...      ...         ...                                                ...
# 73263  73263       73264                     I am a developer by profession
# 73264  73264       73265                     I am a developer by profession
# 73265  73265       73266  I am not primarily a developer, but I write co...
# 73266  73266       73267                     I am a developer by profession
# 73267  73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert  ...        TimeSearching  \
# 0                                   NaN  ...                  NaN
# 1                                   NaN  ...                  NaN
# 2                                   NaN  ...                  NaN
# 3                                   NaN  ...                  NaN
# 4                                   NaN  ...                  NaN
# ...                                 ...  ...                  ...
# 73263                             Udemy  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX  ...  30-60 minutes a day
# 73266                               NaN  ...                  NaN
# 73267                 Udemy;Pluralsight  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73221 rows x 80 columns]

# %% [markdown]
# < > can be used as part of the filter for numeric values

# %%
myfilter_salery = (df['Country'] == 'Israel') & (df['ConvertedCompYearly'] > 100000)
df.loc[myfilter_salery]
# Out:
#        index  ResponseId                      MainBranch  \
# 3          3           4  I am a developer by profession
# 96        96          97  I am a developer by profession
# 138      138         139  I am a developer by profession
# 259      259         260  I am a developer by profession
# 264      264         265  I am a developer by profession
# ...      ...         ...                             ...
# 71494  71494       71495  I am a developer by profession
# 71632  71632       71633  I am a developer by profession
# 72545  72545       72546  I am a developer by profession
# 72961  72961       72962  I am a developer by profession
# 73001  73001       73002  I am a developer by profession
#
#                                               Employment  \
# 3                                    Employed, full-time
# 96                                   Employed, full-time
# 138                                  Employed, full-time
# 259                                  Employed, full-time
# 264                                  Employed, full-time
# ...                                                  ...
# 71494                                Employed, full-time
# 71632  Independent contractor, freelancer, or self-em...
# 72545                                Employed, full-time
# 72961                                Employed, full-time
# 73001                                Employed, full-time
#
#                                  RemoteWork  \
# 3                              Fully remote
# 96     Hybrid (some remote, some in-person)
# 138    Hybrid (some remote, some in-person)
# 259    Hybrid (some remote, some in-person)
# 264    Hybrid (some remote, some in-person)
# ...                                     ...
# 71494  Hybrid (some remote, some in-person)
# 71632                          Fully remote
# 72545  Hybrid (some remote, some in-person)
# 72961  Hybrid (some remote, some in-person)
# 73001  Hybrid (some remote, some in-person)
#
#                                CodingActivities  \
# 3                  I don’t code outside of work
# 96                                        Hobby
# 138                                       Hobby
# 259                                       Hobby
# 264                I don’t code outside of work
# ...                                         ...
# 71494  Hobby;Contribute to open-source projects
# 71632              I don’t code outside of work
# 72545              I don’t code outside of work
# 72961              I don’t code outside of work
# 73001            Hobby;Bootstrapping a business
#
#                                                  EdLevel  \
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 96          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 138         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 259         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 264         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 71494                                     Something else
# 71632  Secondary school (e.g. American high school, G...
# 72545    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72961       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73001                          Primary/elementary school
#
#                                                LearnCode  \
# 3      Books / Physical media;School (i.e., Universit...
# 96     Other online resources (e.g., videos, blogs, f...
# 138    Other online resources (e.g., videos, blogs, f...
# 259    Books / Physical media;Other online resources ...
# 264    School (i.e., University, College, etc);On the...
# ...                                                  ...
# 71494  Books / Physical media;Other online resources ...
# 71632  Books / Physical media;Other online resources ...
# 72545  Books / Physical media;Other online resources ...
# 72961  School (i.e., University, College, etc);On the...
# 73001  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 3                                                    NaN
# 96     Technical documentation;Blogs;Stack Overflow;C...
# 138    Technical documentation;Blogs;Stack Overflow;H...
# 259    Technical documentation;Blogs;Written Tutorial...
# 264                                                  NaN
# ...                                                  ...
# 71494  Technical documentation;Blogs;Written Tutorial...
# 71632  Technical documentation;Blogs;Stack Overflow;V...
# 72545  Technical documentation;Written Tutorials;Stac...
# 72961                                                NaN
# 73001                                                NaN
#
#                LearnCodeCoursesCert  ...         TimeSearching  \
# 3                               NaN  ...                   NaN
# 96                              NaN  ...  60-120 minutes a day
# 138                             NaN  ...   30-60 minutes a day
# 259                             NaN  ...   30-60 minutes a day
# 264                             NaN  ...                   NaN
# ...                             ...  ...                   ...
# 71494  Udemy;Codecademy;Pluralsight  ...   30-60 minutes a day
# 71632                         Udemy  ...                   NaN
# 72545                           NaN  ...   15-30 minutes a day
# 72961                           NaN  ...   30-60 minutes a day
# 73001                         Other  ...                   NaN
#
#              TimeAnswering      Onboarding  \
# 3                      NaN             NaN
# 96     15-30 minutes a day  Somewhat short
# 138    15-30 minutes a day       Very long
# 259    30-60 minutes a day   Somewhat long
# 264                    NaN             NaN
# ...                    ...             ...
# 71494  30-60 minutes a day      Just right
# 71632                  NaN             NaN
# 72545  30-60 minutes a day             NaN
# 72961  30-60 minutes a day      Just right
# 73001                  NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 3                                                    NaN         NaN
# 96     Microservices;Continuous integration (CI) and ...          No
# 138    Developer portal or other central places to fi...          No
# 259    DevOps function;Microservices;Automated testin...         Yes
# 264                                                  NaN         NaN
# ...                                                  ...         ...
# 71494    DevOps function;Microservices;Automated testing          No
# 71632                                                NaN         NaN
# 72545                                                NaN         Yes
# 72961  Innersource initiative;DevOps function;Microse...         Yes
# 73001                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 3             NaN         NaN  Appropriate in length
# 96             No         Yes               Too long
# 138           Yes         Yes               Too long
# 259            No         Yes  Appropriate in length
# 264           NaN         NaN  Appropriate in length
# ...           ...         ...                    ...
# 71494         Yes         Yes  Appropriate in length
# 71632         NaN         NaN  Appropriate in length
# 72545          No         Yes  Appropriate in length
# 72961         Yes         Yes  Appropriate in length
# 73001         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 3                            Easy            215232.0
# 96                           Easy            143484.0
# 138                          Easy            197292.0
# 259                          Easy            197292.0
# 264                          Easy            190925.0
# ...                           ...                 ...
# 71494                        Easy            164411.0
# 71632                        Easy            157836.0
# 72545  Neither easy nor difficult            105013.0
# 72961  Neither easy nor difficult            283982.0
# 73001                        Easy            215232.0
#
# [289 rows x 80 columns]

# %% [markdown]
# To modify the list of filtered data columns

# %%
df.loc[myfilter_salery,['Country','LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#       Country                LanguageHaveWorkedWith  ConvertedCompYearly
# 3      Israel          C#;JavaScript;SQL;TypeScript             215232.0
# 96     Israel  Go;HTML/CSS;JavaScript;Ruby;Rust;SQL             143484.0
# 138    Israel                      PHP;Python;Scala             197292.0
# 259    Israel             Clojure;Python;Ruby;Scala             197292.0
# 264    Israel      Bash/Shell;Java;Python;Scala;SQL             190925.0
# ...       ...                                   ...                  ...
# 71494  Israel   Bash/Shell;Groovy;JavaScript;Python             164411.0
# 71632  Israel                                  C;C#             157836.0
# 72545  Israel                                     C             105013.0
# 72961  Israel                                Python             283982.0
# 73001  Israel               HTML/CSS;JavaScript;PHP             215232.0
#
# [289 rows x 3 columns]

# %% [markdown]
# Var is set to include the specific entities,
# The isin will include each element in the DataFrame is contained in values.

# %%
countries = ['United States','Israel','India']
country_filter = df['Country'].isin(countries)
df.loc[country_filter]
# Out:
#        index  ResponseId                                         MainBranch  \
# 3          3           4                     I am a developer by profession
# 6          6           7                        I code primarily as a hobby
# 7          7           8                     I am a developer by profession
# 24        24          25                     I am a developer by profession
# 27        27          28                     I am a developer by profession
# ...      ...         ...                                                ...
# 73193  73193       73194  I used to be a developer by profession, but no...
# 73238  73238       73239                     I am a developer by profession
# 73255  73255       73256                     I am a developer by profession
# 73257  73257       73258                              I am learning to code
# 73258  73258       73259                     I am a developer by profession
#
#                                               Employment  \
# 3                                    Employed, full-time
# 6                                     Student, part-time
# 7                     Not employed, but looking for work
# 24     Independent contractor, freelancer, or self-em...
# 27                Not employed, and not looking for work
# ...                                                  ...
# 73193                                Employed, full-time
# 73238                                Employed, full-time
# 73255                                Employed, full-time
# 73257                                 Student, full-time
# 73258                                Employed, full-time
#
#                                  RemoteWork               CodingActivities  \
# 3                              Fully remote   I don’t code outside of work
# 6                                       NaN                            NaN
# 7                                       NaN                            NaN
# 24                             Fully remote   I don’t code outside of work
# 27                                      NaN                            NaN
# ...                                     ...                            ...
# 73193                          Fully remote                          Hobby
# 73238  Hybrid (some remote, some in-person)   I don’t code outside of work
# 73255  Hybrid (some remote, some in-person)  Hobby;Freelance/contract work
# 73257                                   NaN                            NaN
# 73258  Hybrid (some remote, some in-person)                          Hobby
#
#                                                  EdLevel  \
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6      Secondary school (e.g. American high school, G...
# 7      Some college/university study without earning ...
# 24     Some college/university study without earning ...
# 27                                        Something else
# ...                                                  ...
# 73193       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73238  Some college/university study without earning ...
# 73255       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73257  Secondary school (e.g. American high school, G...
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 3      Books / Physical media;School (i.e., Universit...
# 6      Other online resources (e.g., videos, blogs, f...
# 7                        Online Courses or Certification
# 24                                                   NaN
# 27     Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73193  Other online resources (e.g., videos, blogs, f...
# 73238  Other online resources (e.g., videos, blogs, f...
# 73255  Other online resources (e.g., videos, blogs, f...
# 73257  Books / Physical media;Other online resources ...
# 73258  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  \
# 3                                                    NaN
# 6              Stack Overflow;Video-based Online Courses
# 7                                                    NaN
# 24                                                   NaN
# 27     Technical documentation;Written Tutorials;Stac...
# ...                                                  ...
# 73193  Technical documentation;Stack Overflow;Video-b...
# 73238  Technical documentation;Blogs;Written Tutorial...
# 73255  Technical documentation;Blogs;Stack Overflow;O...
# 73257  Technical documentation;Blogs;Written Tutorial...
# 73258  Stack Overflow;Video-based Online Courses;Onli...
#
#            LearnCodeCoursesCert  ...         TimeSearching  \
# 3                           NaN  ...                   NaN
# 6                           NaN  ...                   NaN
# 7                Coursera;Udemy  ...                   NaN
# 24                          NaN  ...                   NaN
# 27                          NaN  ...                   NaN
# ...                         ...  ...                   ...
# 73193            Coursera;Udemy  ...   15-30 minutes a day
# 73238  Udemy;Codecademy;Udacity  ...   30-60 minutes a day
# 73255                       NaN  ...  60-120 minutes a day
# 73257                       NaN  ...                   NaN
# 73258            Coursera;Udemy  ...   15-30 minutes a day
#
#                     TimeAnswering     Onboarding  \
# 3                             NaN            NaN
# 6                             NaN            NaN
# 7                             NaN            NaN
# 24                            NaN            NaN
# 27                            NaN            NaN
# ...                           ...            ...
# 73193         15-30 minutes a day  Somewhat long
# 73238        60-120 minutes a day  Somewhat long
# 73255  Less than 15 minutes a day  Somewhat long
# 73257                         NaN            NaN
# 73258         15-30 minutes a day     Just right
#
#                                         ProfessionalTech TrueFalse_1  \
# 3                                                    NaN         NaN
# 6                                                    NaN         NaN
# 7                                                    NaN         NaN
# 24                                                   NaN         NaN
# 27                                                   NaN         NaN
# ...                                                  ...         ...
# 73193  DevOps function;Microservices;Developer portal...         Yes
# 73238  DevOps function;Microservices;Developer portal...         Yes
# 73255  DevOps function;Microservices;Continuous integ...         Yes
# 73257                                                NaN         NaN
# 73258  DevOps function;Microservices;Developer portal...         Yes
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 3             NaN         NaN  Appropriate in length
# 6             NaN         NaN  Appropriate in length
# 7             NaN         NaN  Appropriate in length
# 24            NaN         NaN              Too short
# 27            NaN         NaN  Appropriate in length
# ...           ...         ...                    ...
# 73193         Yes         Yes  Appropriate in length
# 73238         Yes         Yes  Appropriate in length
# 73255         Yes         Yes               Too long
# 73257         NaN         NaN              Too short
# 73258         Yes         Yes               Too long
#
#                        SurveyEase ConvertedCompYearly
# 3                            Easy            215232.0
# 6                            Easy                 NaN
# 7                            Easy                 NaN
# 24                           Easy                 NaN
# 27                           Easy                 NaN
# ...                           ...                 ...
# 73193                        Easy                 NaN
# 73238                        Easy                 NaN
# 73255  Neither easy nor difficult                 NaN
# 73257                        Easy                 NaN
# 73258  Neither easy nor difficult                 NaN
#
# [7434 rows x 80 columns]

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %% [markdown]
# The str function can search for a specific string within a column as part of the filter
# The na=False is used to filter out the NaN (not a number)

# %%
langfilter = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df[langfilter]
df.loc[langfilter,'LanguageHaveWorkedWith']
# Out:
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 11       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 14             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 16                                    C#;Java;PHP;Python;R
#                                ...
# 73257                                         C;Python;SQL
# 73261    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %% [markdown]
# To rename a name of a column
# To modify the data, need to add the inplace=True, good practice first to check results of modification and before actualy modifing the data

# %%
df.rename(columns={'Employment': 'EmploymentStatus','EdLevel':'Education_Level'})
#df.rename(columns={'Employment': 'EmploymentStatus','EdLevel':'Education_Level'}, inplace=True)
# Out:
#        index  ResponseId                                         MainBranch  \
# 0          0           1                                      None of these
# 1          1           2                     I am a developer by profession
# 2          2           3  I am not primarily a developer, but I write co...
# 3          3           4                     I am a developer by profession
# 4          4           5                     I am a developer by profession
# ...      ...         ...                                                ...
# 73263  73263       73264                     I am a developer by profession
# 73264  73264       73265                     I am a developer by profession
# 73265  73265       73266  I am not primarily a developer, but I write co...
# 73266  73266       73267                     I am a developer by profession
# 73267  73267       73268  I used to be a developer by profession, but no...
#
#                                         EmploymentStatus  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                        Education_Level  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert  ...        TimeSearching  \
# 0                                   NaN  ...                  NaN
# 1                                   NaN  ...                  NaN
# 2                                   NaN  ...                  NaN
# 3                                   NaN  ...                  NaN
# 4                                   NaN  ...                  NaN
# ...                                 ...  ...                  ...
# 73263                             Udemy  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX  ...  30-60 minutes a day
# 73266                               NaN  ...                  NaN
# 73267                 Udemy;Pluralsight  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 80 columns]

# %% [markdown]
# To update a single Value using the loc function
# Dataframe.loc[num of row, ['col Name']] = ['new value']

# %%
# df.loc[3, 'EmploymentStatus'] = 'UnEmployed'
df.loc[3, ['EmploymentStatus','Education_Level']] = ['UnEmployed','Professor']

# %% [markdown]
# To change YES / NO Values to Boolean True False

# %%
df['SOAccount'].map({'Yes':True, 'No':False})
# Out:
# 0         NaN
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 73263    True
# 73264     NaN
# 73265    True
# 73266    True
# 73267    True
# Name: SOAccount, Length: 73268, dtype: object

# %% [markdown]
# The inplace option is not valid here, need to apply the changes to the collumn
# In case there are more values on top of YES NO, you should use

# %%
df['SOAccount'].replace({'Yes':True, 'No':False})
# Out:
# 0                            NaN
# 1                           True
# 2                           True
# 3                           True
# 4                           True
#                   ...
# 73263                       True
# 73264    Not sure/can't remember
# 73265                       True
# 73266                       True
# 73267                       True
# Name: SOAccount, Length: 73268, dtype: object

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes':True, 'No':False})

# %%
df['SOAccount']
# Out:
# 0         NaN
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 73263    True
# 73264     NaN
# 73265    True
# 73266    True
# 73267    True
# Name: SOAccount, Length: 73268, dtype: object

# %% [markdown]
# To concatenate 2 columns into a new one

# %%
df['Age&Gender'] = df['Age'] + ' ' + df['Gender']  
df['Age&Gender']
# Out:
# 0                        NaN
# 1                        NaN
# 2        25-34 years old Man
# 3        35-44 years old Man
# 4                        NaN
#                 ...
# 73263    25-34 years old Man
# 73264    25-34 years old Man
# 73265    55-64 years old Man
# 73266    55-64 years old Man
# 73267    25-34 years old Man
# Name: Age&Gender, Length: 73268, dtype: object

# %% [markdown]
# To Remove Columns

# %%
df.drop(columns=['Trans','Ethnicity'], inplace=True)

# %% [markdown]
# # split col to multiple columns
#
# To Split one col to several cols
# Split into new cols with names

# %%
df['DevType'].str.split(',', expand=True)
#df[['Dev1', 'Dev2', 'Dev3']] = df['DevType'].str.split(',', expand=True)
# Out:
#                                                       0   \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                              Developer
# 4                                              Developer
# ...                                                  ...
# 73263                                          Developer
# 73264      Data scientist or machine learning specialist
# 73265                                          Developer
# 73266                                          Developer
# 73267                                          Developer
#
#                           1   \
# 0                        NaN
# 1                        NaN
# 2         front-end;Engineer
# 3                 full-stack
# 4        front-end;Developer
# ...                      ...
# 73263               back-end
# 73264                   None
# 73265   full-stack;Developer
# 73266    front-end;Developer
# 73267     front-end;Engineer
#
#                                                       2   \
# 0                                                    NaN
# 1                                                    NaN
# 2                                          data;Engineer
# 3                                                   None
# 4                                   full-stack;Developer
# ...                                                  ...
# 73263                                               None
# 73264                                               None
# 73265   desktop or enterprise applications;System adm...
# 73266                 desktop or enterprise applications
# 73267                                      data;Engineer
#
#                                 3   \
# 0                              NaN
# 1                              NaN
# 2                 site reliability
# 3                             None
# 4               back-end;Developer
# ...                            ...
# 73263                         None
# 73264                         None
# 73265                         None
# 73266                         None
# 73267   site reliability;Developer
#
#                                                   4                    5   \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                               None                 None
# 3                                               None                 None
# 4       desktop or enterprise applications;Developer           QA or test
# ...                                              ...                  ...
# 73263                                           None                 None
# 73264                                           None                 None
# 73265                                           None                 None
# 73266                                           None                 None
# 73267                           full-stack;Developer   back-end;Developer
#
#                                                   6   \
# 0                                                NaN
# 1                                                NaN
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 73263                                           None
# 73264                                           None
# 73265                                           None
# 73266                                           None
# 73267   desktop or enterprise applications;Developer
#
#                                   7   \
# 0                                NaN
# 1                                NaN
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 73263                           None
# 73264                           None
# 73265                           None
# 73266                           None
# 73267   QA or test;Student;Developer
#
#                                                       8   \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 73263                                               None
# 73264                                               None
# 73265                                               None
# 73266                                               None
# 73267   mobile;Academic researcher;DevOps specialist;...
#
#                                                 9   \
# 0                                              NaN
# 1                                              NaN
# 2                                             None
# 3                                             None
# 4                                             None
# ...                                            ...
# 73263                                         None
# 73264                                         None
# 73265                                         None
# 73266                                         None
# 73267   embedded applications or devices;Developer
#
#                                                       10    11    12
# 0                                                    NaN   NaN   NaN
# 1                                                    NaN   NaN   NaN
# 2                                                   None  None  None
# 3                                                   None  None  None
# 4                                                   None  None  None
# ...                                                  ...   ...   ...
# 73263                                               None  None  None
# 73264                                               None  None  None
# 73265                                               None  None  None
# 73266                                               None  None  None
# 73267   game or graphics;Cloud infrastructure enginee...  None  None
#
# [73268 rows x 13 columns]

# %% [markdown]
# To add a new row, a new dicrionary needs to be created
# A new DataFrame will contain the Pandas DataFrame of the dictionary

# %%
NewRow = {
    'ResponseId':['65000','65001','65002'],
    'MainBranch':['I dont know nothing', 'Im an expert', 'Im faking'],
    'Employment':['full time',' לא עובד', 'part time'],
    'RemoteWork':['office', 'home', 'hybrid'],
    'CodingActivities':['hobby', 'volunteer', 'Freelance']    
}
NewRowDf = pd.DataFrame(NewRow)
NewRowDf.set_index('ResponseId', inplace=True, drop=True)
NewRowDf
# Out:
#                      MainBranch Employment RemoteWork CodingActivities
# ResponseId
# 65000       I dont know nothing  full time     office            hobby
# 65001              Im an expert    לא עובד       home        volunteer
# 65002                 Im faking  part time     hybrid        Freelance

# %% [markdown]
# Append the new dictioanry to the table

# %%
df = pd.concat([df, NewRowDf])

# %% [markdown]
# # Delete a row
#
# Delete a row based on index number

# %%
df.drop('65000')
# Out:
#          index  ResponseId                                         MainBranch  \
# 0          0.0         1.0                                      None of these
# 1          1.0         2.0                     I am a developer by profession
# 2          2.0         3.0  I am not primarily a developer, but I write co...
# 3          3.0         4.0                     I am a developer by profession
# 4          4.0         5.0                     I am a developer by profession
# ...        ...         ...                                                ...
# 73265  73265.0     73266.0  I am not primarily a developer, but I write co...
# 73266  73266.0     73267.0                     I am a developer by profession
# 73267  73267.0     73268.0  I used to be a developer by profession, but no...
# 65001      NaN         NaN                                       Im an expert
# 65002      NaN         NaN                                          Im faking
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
# 65001                                            לא עובד
# 65002                                          part time
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
# 65001                                  home
# 65002                                hybrid
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
# 65001                                          volunteer
# 65002                                          Freelance
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65001                                              NaN
# 65002                                              NaN
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
# 65001                                                NaN
# 65002                                                NaN
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
# 65001                                                NaN
# 65002                                                NaN
#
#                    LearnCodeCoursesCert  ... ProfessionalTech TrueFalse_1  \
# 0                                   NaN  ...              NaN         NaN
# 1                                   NaN  ...              NaN         NaN
# 2                                   NaN  ...              NaN         NaN
# 3                                   NaN  ...              NaN         NaN
# 4                                   NaN  ...              NaN         NaN
# ...                                 ...  ...              ...         ...
# 73265  Udemy;Codecademy;Pluralsight;edX  ...    None of these          No
# 73266                               NaN  ...              NaN         NaN
# 73267                 Udemy;Pluralsight  ...              NaN         NaN
# 65001                               NaN  ...              NaN         NaN
# 65002                               NaN  ...              NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
# 65001         NaN         NaN                    NaN
# 65002         NaN         NaN                    NaN
#
#                        SurveyEase ConvertedCompYearly EmploymentStatus  \
# 0                             NaN                 NaN              NaN
# 1                       Difficult                 NaN              NaN
# 2      Neither easy nor difficult             40205.0              NaN
# 3                            Easy            215232.0       UnEmployed
# 4                            Easy                 NaN              NaN
# ...                           ...                 ...              ...
# 73265                        Easy                 NaN              NaN
# 73266                        Easy                 NaN              NaN
# 73267                        Easy                 NaN              NaN
# 65001                         NaN                 NaN              NaN
# 65002                         NaN                 NaN              NaN
#
#        Education_Level           Age&Gender
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN  25-34 years old Man
# 3            Professor  35-44 years old Man
# 4                  NaN                  NaN
# ...                ...                  ...
# 73265              NaN  55-64 years old Man
# 73266              NaN  55-64 years old Man
# 73267              NaN  25-34 years old Man
# 65001              NaN                  NaN
# 65002              NaN                  NaN
#
# [73270 rows x 81 columns]

# %% [markdown]
# Delete a row based on a specific value (returnes the index num of the row)

# %%
df.drop(index=df[df['MainBranch']=='Im faking'].index)
# Out:
#          index  ResponseId                                         MainBranch  \
# 0          0.0         1.0                                      None of these
# 1          1.0         2.0                     I am a developer by profession
# 2          2.0         3.0  I am not primarily a developer, but I write co...
# 3          3.0         4.0                     I am a developer by profession
# 4          4.0         5.0                     I am a developer by profession
# ...        ...         ...                                                ...
# 73265  73265.0     73266.0  I am not primarily a developer, but I write co...
# 73266  73266.0     73267.0                     I am a developer by profession
# 73267  73267.0     73268.0  I used to be a developer by profession, but no...
# 65000      NaN         NaN                                I dont know nothing
# 65001      NaN         NaN                                       Im an expert
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
# 65000                                          full time
# 65001                                            לא עובד
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
# 65000                                office
# 65001                                  home
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
# 65000                                              hobby
# 65001                                          volunteer
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65000                                              NaN
# 65001                                              NaN
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
# 65000                                                NaN
# 65001                                                NaN
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
# 65000                                                NaN
# 65001                                                NaN
#
#                    LearnCodeCoursesCert  ... ProfessionalTech TrueFalse_1  \
# 0                                   NaN  ...              NaN         NaN
# 1                                   NaN  ...              NaN         NaN
# 2                                   NaN  ...              NaN         NaN
# 3                                   NaN  ...              NaN         NaN
# 4                                   NaN  ...              NaN         NaN
# ...                                 ...  ...              ...         ...
# 73265  Udemy;Codecademy;Pluralsight;edX  ...    None of these          No
# 73266                               NaN  ...              NaN         NaN
# 73267                 Udemy;Pluralsight  ...              NaN         NaN
# 65000                               NaN  ...              NaN         NaN
# 65001                               NaN  ...              NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
# 65000         NaN         NaN                    NaN
# 65001         NaN         NaN                    NaN
#
#                        SurveyEase ConvertedCompYearly EmploymentStatus  \
# 0                             NaN                 NaN              NaN
# 1                       Difficult                 NaN              NaN
# 2      Neither easy nor difficult             40205.0              NaN
# 3                            Easy            215232.0       UnEmployed
# 4                            Easy                 NaN              NaN
# ...                           ...                 ...              ...
# 73265                        Easy                 NaN              NaN
# 73266                        Easy                 NaN              NaN
# 73267                        Easy                 NaN              NaN
# 65000                         NaN                 NaN              NaN
# 65001                         NaN                 NaN              NaN
#
#        Education_Level           Age&Gender
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN  25-34 years old Man
# 3            Professor  35-44 years old Man
# 4                  NaN                  NaN
# ...                ...                  ...
# 73265              NaN  55-64 years old Man
# 73266              NaN  55-64 years old Man
# 73267              NaN  25-34 years old Man
# 65000              NaN                  NaN
# 65001              NaN                  NaN
#
# [73270 rows x 81 columns]

# %% [markdown]
# Another alternative to set a var with the condition

# %%
#my_drop_filter = df['MainBranch']=='Im faking'
#df.drop(index=df[df[my_drop_filter].index)

# %% [markdown]
# # Sort Data

# %%
df.sort_values(by='MainBranch')
#df.sort_values(by='MainBranch', ascending=False)
# Out:
#          index  ResponseId                      MainBranch  \
# 36635  36635.0     36636.0  I am a developer by profession
# 44091  44091.0     44092.0  I am a developer by profession
# 44092  44092.0     44093.0  I am a developer by profession
# 44093  44093.0     44094.0  I am a developer by profession
# 44094  44094.0     44095.0  I am a developer by profession
# ...        ...         ...                             ...
# 61073  61073.0     61074.0                   None of these
# 61085  61085.0     61086.0                   None of these
# 61102  61102.0     61103.0                   None of these
# 60988  60988.0     60989.0                   None of these
# 0          0.0         1.0                   None of these
#
#                 Employment                            RemoteWork  \
# 36635  Employed, full-time                          Fully remote
# 44091  Employed, full-time  Hybrid (some remote, some in-person)
# 44092  Employed, full-time  Hybrid (some remote, some in-person)
# 44093  Employed, full-time                          Fully remote
# 44094  Employed, full-time                          Fully remote
# ...                    ...                                   ...
# 61073                  NaN                                   NaN
# 61085                  NaN                                   NaN
# 61102                  NaN                                   NaN
# 60988                  NaN                                   NaN
# 0                      NaN                                   NaN
#
#                      CodingActivities  \
# 36635    I don’t code outside of work
# 44091                           Hobby
# 44092         Other (please specify):
# 44093  Hobby;Bootstrapping a business
# 44094         Freelance/contract work
# ...                               ...
# 61073                             NaN
# 61085                             NaN
# 61102                             NaN
# 60988                             NaN
# 0                                 NaN
#
#                                                EdLevel  \
# 36635     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44091  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44092                                   Something else
# 44093     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44094  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 61073                                              NaN
# 61085                                              NaN
# 61102                                              NaN
# 60988                                              NaN
# 0                                                  NaN
#
#                                                LearnCode  \
# 36635  Books / Physical media;Other online resources ...
# 44091  Books / Physical media;School (i.e., Universit...
# 44092  Friend or family member;Other online resources...
# 44093  Other online resources (e.g., videos, blogs, f...
# 44094  Books / Physical media;Other online resources ...
# ...                                                  ...
# 61073                                                NaN
# 61085                                                NaN
# 61102                                                NaN
# 60988                                                NaN
# 0                                                    NaN
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 36635  Technical documentation;Blogs;Written Tutorial...                  NaN
# 44091                                                NaN                  NaN
# 44092  Video-based Online Courses;Written-based Onlin...                  NaN
# 44093  Technical documentation;Blogs;Written Tutorial...                  NaN
# 44094  Technical documentation;Stack Overflow;Online ...    Udemy;Pluralsight
# ...                                                  ...                  ...
# 61073                                                NaN                  NaN
# 61085                                                NaN                  NaN
# 61102                                                NaN                  NaN
# 60988                                                NaN                  NaN
# 0                                                    NaN                  NaN
#
#        ...                                   ProfessionalTech TrueFalse_1  \
# 36635  ...  DevOps function;Developer portal or other cent...          No
# 44091  ...                                                NaN         NaN
# 44092  ...  Continuous integration (CI) and (more often) c...         Yes
# 44093  ...  Innersource initiative;DevOps function;Microse...          No
# 44094  ...                                                NaN         NaN
# ...    ...                                                ...         ...
# 61073  ...                                                NaN         NaN
# 61085  ...                                                NaN         NaN
# 61102  ...                                                NaN         NaN
# 60988  ...                                                NaN         NaN
# 0      ...                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength SurveyEase  \
# 36635          No         Yes  Appropriate in length       Easy
# 44091         NaN         NaN  Appropriate in length       Easy
# 44092         Yes         Yes  Appropriate in length       Easy
# 44093         Yes         Yes               Too long       Easy
# 44094         NaN         NaN  Appropriate in length       Easy
# ...           ...         ...                    ...        ...
# 61073         NaN         NaN                    NaN        NaN
# 61085         NaN         NaN                    NaN        NaN
# 61102         NaN         NaN                    NaN        NaN
# 60988         NaN         NaN                    NaN        NaN
# 0             NaN         NaN                    NaN        NaN
#
#       ConvertedCompYearly EmploymentStatus  Education_Level  \
# 36635             75384.0              NaN              NaN
# 44091             99804.0              NaN              NaN
# 44092              4332.0              NaN              NaN
# 44093             56568.0              NaN              NaN
# 44094            156168.0              NaN              NaN
# ...                   ...              ...              ...
# 61073                 NaN              NaN              NaN
# 61085                 NaN              NaN              NaN
# 61102                 NaN              NaN              NaN
# 60988                 NaN              NaN              NaN
# 0                     NaN              NaN              NaN
#
#                   Age&Gender
# 36635  18-24 years old Woman
# 44091    35-44 years old Man
# 44092  25-34 years old Woman
# 44093    25-34 years old Man
# 44094    45-54 years old Man
# ...                      ...
# 61073                    NaN
# 61085                    NaN
# 61102                    NaN
# 60988                    NaN
# 0                        NaN
#
# [73271 rows x 81 columns]

# %% [markdown]
# Sort multi Values

# %%
df.sort_values(by=['MainBranch','RemoteWork'])
# Out:
#          index  ResponseId                      MainBranch  \
# 58        58.0        59.0  I am a developer by profession
# 66        66.0        67.0  I am a developer by profession
# 74        74.0        75.0  I am a developer by profession
# 89        89.0        90.0  I am a developer by profession
# 99        99.0       100.0  I am a developer by profession
# ...        ...         ...                             ...
# 73109  73109.0     73110.0                   None of these
# 73157  73157.0     73158.0                   None of these
# 73201  73201.0     73202.0                   None of these
# 73215  73215.0     73216.0                   None of these
# 73243  73243.0     73244.0                   None of these
#
#                 Employment      RemoteWork              CodingActivities  \
# 58     Employed, full-time  Full in-person                         Hobby
# 66     Employed, full-time  Full in-person      Bootstrapping a business
# 74     Employed, full-time  Full in-person  I don’t code outside of work
# 89     Employed, full-time  Full in-person  I don’t code outside of work
# 99     Employed, full-time  Full in-person                         Hobby
# ...                    ...             ...                           ...
# 73109                  NaN             NaN                           NaN
# 73157                  NaN             NaN                           NaN
# 73201                  NaN             NaN                           NaN
# 73215                  NaN             NaN                           NaN
# 73243                  NaN             NaN                           NaN
#
#                                                EdLevel  \
# 58     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 66     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 74        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 89        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 99                 Associate degree (A.A., A.S., etc.)
# ...                                                ...
# 73109                                              NaN
# 73157                                              NaN
# 73201                                              NaN
# 73215                                              NaN
# 73243                                              NaN
#
#                                                LearnCode  \
# 58     Books / Physical media;Other online resources ...
# 66     School (i.e., University, College, etc);Colleague
# 74               School (i.e., University, College, etc)
# 89               School (i.e., University, College, etc)
# 99     Books / Physical media;Other online resources ...
# ...                                                  ...
# 73109                                                NaN
# 73157                                                NaN
# 73201                                                NaN
# 73215                                                NaN
# 73243                                                NaN
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 58     Technical documentation;Blogs;Written Tutorial...                  NaN
# 66                                                   NaN                  NaN
# 74                                                   NaN                  NaN
# 89                                                   NaN                  NaN
# 99     Technical documentation;Blogs;Stack Overflow;O...                  NaN
# ...                                                  ...                  ...
# 73109                                                NaN                  NaN
# 73157                                                NaN                  NaN
# 73201                                                NaN                  NaN
# 73215                                                NaN                  NaN
# 73243                                                NaN                  NaN
#
#        ...                                   ProfessionalTech TrueFalse_1  \
# 58     ...  Continuous integration (CI) and (more often) c...         Yes
# 66     ...                                      None of these         Yes
# 74     ...                                                NaN         NaN
# 89     ...                                      None of these         Yes
# 99     ...                                                NaN         NaN
# ...    ...                                                ...         ...
# 73109  ...                                                NaN         NaN
# 73157  ...                                                NaN         NaN
# 73201  ...                                                NaN         NaN
# 73215  ...                                                NaN         NaN
# 73243  ...                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 58             No          No  Appropriate in length
# 66             No         Yes  Appropriate in length
# 74            NaN         NaN  Appropriate in length
# 89            Yes         Yes  Appropriate in length
# 99            NaN         NaN  Appropriate in length
# ...           ...         ...                    ...
# 73109         NaN         NaN                    NaN
# 73157         NaN         NaN                    NaN
# 73201         NaN         NaN                    NaN
# 73215         NaN         NaN                    NaN
# 73243         NaN         NaN                    NaN
#
#                        SurveyEase ConvertedCompYearly EmploymentStatus  \
# 58     Neither easy nor difficult                 NaN              NaN
# 66                           Easy             24924.0              NaN
# 74                           Easy             50220.0              NaN
# 89     Neither easy nor difficult             57288.0              NaN
# 99     Neither easy nor difficult             12024.0              NaN
# ...                           ...                 ...              ...
# 73109                         NaN                 NaN              NaN
# 73157                         NaN                 NaN              NaN
# 73201                         NaN                 NaN              NaN
# 73215                         NaN                 NaN              NaN
# 73243                         NaN                 NaN              NaN
#
#        Education_Level           Age&Gender
# 58                 NaN  25-34 years old Man
# 66                 NaN  45-54 years old Man
# 74                 NaN  35-44 years old Man
# 89                 NaN  25-34 years old Man
# 99                 NaN  25-34 years old Man
# ...                ...                  ...
# 73109              NaN                  NaN
# 73157              NaN                  NaN
# 73201              NaN                  NaN
# 73215              NaN                  NaN
# 73243              NaN                  NaN
#
# [73271 rows x 81 columns]

# %% [markdown]
# Sort multi cols with different ascending / descending

# %%
df.sort_values(by=['MainBranch','RemoteWork'], ascending=[False,True])
# Out:
#          index  ResponseId                      MainBranch  \
# 0          0.0         1.0                   None of these
# 30        30.0        31.0                   None of these
# 86        86.0        87.0                   None of these
# 146      146.0       147.0                   None of these
# 190      190.0       191.0                   None of these
# ...        ...         ...                             ...
# 73150  73150.0     73151.0  I am a developer by profession
# 73186  73186.0     73187.0  I am a developer by profession
# 73225  73225.0     73226.0  I am a developer by profession
# 73239  73239.0     73240.0  I am a developer by profession
# 73244  73244.0     73245.0  I am a developer by profession
#
#                                Employment RemoteWork CodingActivities  \
# 0                                     NaN        NaN              NaN
# 30                                    NaN        NaN              NaN
# 86                                    NaN        NaN              NaN
# 146                                   NaN        NaN              NaN
# 190                                   NaN        NaN              NaN
# ...                                   ...        ...              ...
# 73150                  Student, full-time        NaN              NaN
# 73186                  Student, part-time        NaN              NaN
# 73225  Not employed, but looking for work        NaN              NaN
# 73239  Not employed, but looking for work        NaN              NaN
# 73244  Not employed, but looking for work        NaN              NaN
#
#                                                  EdLevel  \
# 0                                                    NaN
# 30                                                   NaN
# 86                                                   NaN
# 146                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 73150  Secondary school (e.g. American high school, G...
# 73186  Some college/university study without earning ...
# 73225    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73239       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73244       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 30                                                   NaN
# 86                                                   NaN
# 146                                                  NaN
# 190                                                  NaN
# ...                                                  ...
# 73150  Books / Physical media;School (i.e., Universit...
# 73186  Books / Physical media;School (i.e., Universit...
# 73225  Books / Physical media;School (i.e., Universit...
# 73239  Books / Physical media;Other online resources ...
# 73244  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                    NaN                  NaN
# 30                                                   NaN                  NaN
# 86                                                   NaN                  NaN
# 146                                                  NaN                  NaN
# 190                                                  NaN                  NaN
# ...                                                  ...                  ...
# 73150                                                NaN                  NaN
# 73186                                                NaN                Udemy
# 73225                                                NaN                  NaN
# 73239  Written Tutorials;Online books;Video-based Onl...  Pluralsight;Udacity
# 73244                   Blogs;Online forum;How-to videos                  NaN
#
#        ... ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# 0      ...              NaN         NaN         NaN         NaN
# 30     ...              NaN         NaN         NaN         NaN
# 86     ...              NaN         NaN         NaN         NaN
# 146    ...              NaN         NaN         NaN         NaN
# 190    ...              NaN         NaN         NaN         NaN
# ...    ...              ...         ...         ...         ...
# 73150  ...              NaN         NaN         NaN         NaN
# 73186  ...              NaN         NaN         NaN         NaN
# 73225  ...              NaN         NaN         NaN         NaN
# 73239  ...              NaN         NaN         NaN         NaN
# 73244  ...              NaN         NaN         NaN         NaN
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly  \
# 0                        NaN                         NaN                 NaN
# 30                       NaN                         NaN                 NaN
# 86                       NaN                         NaN                 NaN
# 146                      NaN                         NaN                 NaN
# 190                      NaN                         NaN                 NaN
# ...                      ...                         ...                 ...
# 73150  Appropriate in length                        Easy                 NaN
# 73186  Appropriate in length                        Easy                 NaN
# 73225  Appropriate in length  Neither easy nor difficult                 NaN
# 73239  Appropriate in length                        Easy                 NaN
# 73244  Appropriate in length                        Easy                 NaN
#
#       EmploymentStatus  Education_Level  \
# 0                  NaN              NaN
# 30                 NaN              NaN
# 86                 NaN              NaN
# 146                NaN              NaN
# 190                NaN              NaN
# ...                ...              ...
# 73150              NaN              NaN
# 73186              NaN              NaN
# 73225              NaN              NaN
# 73239              NaN              NaN
# 73244              NaN              NaN
#
#                                        Age&Gender
# 0                                             NaN
# 30                                            NaN
# 86                                            NaN
# 146                                           NaN
# 190                                           NaN
# ...                                           ...
# 73150                         18-24 years old Man
# 73186                         25-34 years old Man
# 73225  45-54 years old Man;Or, in your own words:
# 73239                       35-44 years old Woman
# 73244                         25-34 years old Man
#
# [73271 rows x 81 columns]
